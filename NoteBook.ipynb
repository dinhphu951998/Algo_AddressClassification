# %%
from IndexAnalyzer import load_databases, variation_map
from Searcher import search_locations_in_trie, search_locations_in_segments
from Utils import normalize_text_but_keep_vietnamese_alphabet, normalize_text_but_keep_accent, \
    normalize_text_and_remove_accent, segment_text


class Solution:

    debug=False

    def __init__(self):
        # list provice, district, ward for private test, do not change for any reason (these file will be provided later with this exact name)

        self.province_path = 'list_province.txt'
        self.district_path = 'list_district.txt'
        self.ward_path = 'list_ward.txt'

        self.tries = {}
        load_databases({
            "province": self.province_path,
            "district": self.district_path,
            "ward": self.ward_path
        }, self.tries)

        self.variation_map = variation_map
        pass

    def process(self, s: str):
        # Preprocess
        s_copy = s[:]

        segments = segment_text(s)
        input_text = normalize_text_but_keep_accent(",".join(segments))

        # Start searching
        results = {"ward": "", "district": "", "province": ""}

        # Search with accents
        result, remaining_text = search_locations_in_trie(self.tries, input_text, results)

        # If the province/district/ward not found, search without accents
        # remaining_text = normalize_text_and_remove_accent(remaining_text)
        # result, remaining_text = search_locations_in_trie(self.tries, remaining_text, results)

        # If the province/district/ward not found, search by segments
        segments = segment_text(remaining_text, False)
        result, remaining_text = search_locations_in_segments(self.tries, segments, results)

        result =  {
            "province": self.tries["province"].get_raw_text(result["province"]),
            "district": self.tries["district"].get_raw_text(result["district"]),
            "ward": self.tries["ward"].get_raw_text(result["ward"]),
        }

        if self.debug:
            print()
            print(f"Original: {s_copy}")
            print(f"Normalized: {normalize_text_but_keep_accent(s_copy)}")
            print(f"Result: {result}")

        return result

runner = Solution()
runner.debug = True

runner.process("Diên Thạnh,,T Khabnh Hòa")


# Not able to solve yet
# runner.process(" T.P Phan Rang-Tháp lhàm  Ninh Thuận")
# runner.process("Điên Hải, Đông Hải, T bạc Liêu")
# Out:
# Original: Diên Thạnh,,T Khabnh Hòa
# Normalized: diênthạnh,,tkhabnhhòa
# Result: {'province': 'Thanh Hóa', 'district': '', 'ward': 'Diên Thạnh'}
# {'province': 'Thanh Hóa', 'district': '', 'ward': 'Diên Thạnh'}

# %%
import json
import time
import pandas as pd
from datetime import datetime
import pandas as pd

from Solution import Solution

debug = False
# CORRECT TESTS
groups_province = {}
groups_district = {'hòa bình': ['Hoà Bình', 'Hòa Bình'], 'kbang': ['Kbang', 'KBang'], 'quy nhơn': ['Qui Nhơn', 'Quy Nhơn']}
groups_ward = {'ái nghĩa': ['ái Nghĩa', 'Ái Nghĩa'], 'ái quốc': ['ái Quốc', 'Ái Quốc'], 'ái thượng': ['ái Thượng', 'Ái Thượng'], 'ái tử': ['ái Tử', 'Ái Tử'], 'ấm hạ': ['ấm Hạ', 'Ấm Hạ'], 'an ấp': ['An ấp', 'An Ấp'], 'ẳng cang': ['ẳng Cang', 'Ẳng Cang'], 'ẳng nưa': ['ẳng Nưa', 'Ẳng Nưa'], 'ẳng tở': ['ẳng Tở', 'Ẳng Tở'], 'an hòa': ['An Hoà', 'An Hòa'], 'ayun': ['Ayun', 'AYun'], 'bắc ái': ['Bắc ái', 'Bắc Ái'], 'bảo ái': ['Bảo ái', 'Bảo Ái'], 'bình hòa': ['Bình Hoà', 'Bình Hòa'], 'châu ổ': ['Châu ổ', 'Châu Ổ'], 'chư á': ['Chư á', 'Chư Á'], 'chư rcăm': ['Chư Rcăm', 'Chư RCăm'], 'cộng hòa': ['Cộng Hoà', 'Cộng Hòa'], 'cò nòi': ['Cò  Nòi', 'Cò Nòi'], 'đại ân 2': ['Đại Ân  2', 'Đại Ân 2'], 'đak ơ': ['Đak ơ', 'Đak Ơ'], "đạ m'ri": ["Đạ M'ri", "Đạ M'Ri"], 'đông hòa': ['Đông Hoà', 'Đông Hòa'], 'đồng ích': ['Đồng ích', 'Đồng Ích'], 'hải châu i': ['Hải Châu  I', 'Hải Châu I'], 'hải hòa': ['Hải Hoà', 'Hải Hòa'], 'hành tín đông': ['Hành Tín  Đông', 'Hành Tín Đông'], 'hiệp hòa': ['Hiệp Hoà', 'Hiệp Hòa'], 'hòa bắc': ['Hoà Bắc', 'Hòa Bắc'], 'hòa bình': ['Hoà Bình', 'Hòa Bình'], 'hòa châu': ['Hoà Châu', 'Hòa Châu'], 'hòa hải': ['Hoà Hải', 'Hòa Hải'], 'hòa hiệp trung': ['Hoà Hiệp Trung', 'Hòa Hiệp Trung'], 'hòa liên': ['Hoà Liên', 'Hòa Liên'], 'hòa lộc': ['Hoà Lộc', 'Hòa Lộc'], 'hòa lợi': ['Hoà Lợi', 'Hòa Lợi'], 'hòa long': ['Hoà Long', 'Hòa Long'], 'hòa mạc': ['Hoà Mạc', 'Hòa Mạc'], 'hòa minh': ['Hoà Minh', 'Hòa Minh'], 'hòa mỹ': ['Hoà Mỹ', 'Hòa Mỹ'], 'hòa phát': ['Hoà Phát', 'Hòa Phát'], 'hòa phong': ['Hoà Phong', 'Hòa Phong'], 'hòa phú': ['Hoà Phú', 'Hòa Phú'], 'hòa phước': ['Hoà Phước', 'Hòa Phước'], 'hòa sơn': ['Hoà Sơn', 'Hòa Sơn'], 'hòa tân': ['Hoà Tân', 'Hòa Tân'], 'hòa thuận': ['Hoà Thuận', 'Hòa Thuận'], 'hòa tiến': ['Hoà Tiến', 'Hòa Tiến'], 'hòa trạch': ['Hoà Trạch', 'Hòa Trạch'], 'hòa vinh': ['Hoà Vinh', 'Hòa Vinh'], 'hương hòa': ['Hương Hoà', 'Hương Hòa'], 'ích hậu': ['ích Hậu', 'Ích Hậu'], 'ít ong': ['ít Ong', 'Ít Ong'], 'khánh hòa': ['Khánh Hoà', 'Khánh Hòa'], 'krông á': ['Krông Á', 'KRông á'], 'lộc hòa': ['Lộc Hoà', 'Lộc Hòa'], 'minh hòa': ['Minh Hoà', 'Minh Hòa'], 'mường ải': ['Mường ải', 'Mường Ải'], 'mường ẳng': ['Mường ẳng', 'Mường Ẳng'], 'nậm ét': ['Nậm ét', 'Nậm Ét'], 'nam hòa': ['Nam Hoà', 'Nam Hòa'], 'na ư': ['Na ư', 'Na Ư'], 'ngã sáu': ['Ngã sáu', 'Ngã Sáu'], 'nghi hòa': ['Nghi Hoà', 'Nghi Hòa'], 'nguyễn úy': ['Nguyễn Uý', 'Nguyễn úy', 'Nguyễn Úy'], 'nhân hòa': ['Nhân Hoà', 'Nhân Hòa'], 'nhơn hòa': ['Nhơn Hoà', 'Nhơn Hòa'], 'nhơn nghĩa a': ['Nhơn nghĩa A', 'Nhơn Nghĩa A'], 'phúc ứng': ['Phúc ứng', 'Phúc Ứng'], 'phước hòa': ['Phước Hoà', 'Phước Hòa'], 'sơn hóa': ['Sơn Hoá', 'Sơn Hóa'], 'tạ an khương đông': ['Tạ An Khương  Đông', 'Tạ An Khương Đông'], 'tạ an khương nam': ['Tạ An Khương  Nam', 'Tạ An Khương Nam'], 'tăng hòa': ['Tăng Hoà', 'Tăng Hòa'], 'tân hòa': ['Tân Hoà', 'Tân Hòa'], 'tân hòa thành': ['Tân Hòa  Thành', 'Tân Hòa Thành'], 'tân khánh trung': ['Tân  Khánh Trung', 'Tân Khánh Trung'], 'tân lợi': ['Tân lợi', 'Tân Lợi'], 'thái hòa': ['Thái Hoà', 'Thái Hòa'], 'thiết ống': ['Thiết ống', 'Thiết Ống'], 'thuận hòa': ['Thuận Hoà', 'Thuận Hòa'], 'thượng ấm': ['Thượng ấm', 'Thượng Ấm'], 'thụy hương': ['Thuỵ Hương', 'Thụy Hương'], 'thủy xuân': ['Thuỷ Xuân', 'Thủy Xuân'], 'tịnh ấn đông': ['Tịnh ấn Đông', 'Tịnh Ấn Đông'], 'tịnh ấn tây': ['Tịnh ấn Tây', 'Tịnh Ấn Tây'], 'triệu ái': ['Triệu ái', 'Triệu Ái'], 'triệu ẩu': ['Triệu ẩu', 'Triệu Ẩu'], 'trung hòa': ['Trung Hoà', 'Trung Hòa'], 'trung ý': ['Trung ý', 'Trung Ý'], 'tùng ảnh': ['Tùng ảnh', 'Tùng Ảnh'], 'úc kỳ': ['úc Kỳ', 'Úc Kỳ'], 'ứng hòe': ['ứng Hoè', 'Ứng Hoè'], 'vĩnh hòa': ['Vĩnh Hoà', 'Vĩnh Hòa'], 'vũ hòa': ['Vũ Hoà', 'Vũ Hòa'], 'xuân ái': ['Xuân ái', 'Xuân Ái'], 'xuân áng': ['Xuân áng', 'Xuân Áng'], 'xuân hòa': ['Xuân Hoà', 'Xuân Hòa'], 'xuất hóa': ['Xuất Hoá', 'Xuất Hóa'], 'ỷ la': ['ỷ La', 'Ỷ La']}
groups_ward.update({1: ['1', '01'], 2: ['2', '02'], 3: ['3', '03'], 4: ['4', '04'], 5: ['5', '05'], 6: ['6', '06'], 7: ['7', '07'], 8: ['8', '08'], 9: ['9', '09']})
def to_same(groups):
    same = {ele: k for k, v in groups.items() for ele in v}
    return same
same_province = to_same(groups_province)
same_district = to_same(groups_district)
same_ward = to_same(groups_ward)
def normalize(text, same_dict):
    return same_dict.get(text, text)

def get_formatted_datetime():
  now = datetime.now()
  formatted_datetime = now.strftime("%Y%m%d_%H%M%S")
  return formatted_datetime

#
TEAM_NAME = f'DEFAULT_NAME_{get_formatted_datetime()}'  # This should be your team name
EXCEL_FILE = f'{TEAM_NAME}.xlsx'
TEST_FILE = 'public.json'
with open(TEST_FILE, encoding='utf-8') as f:
    data = json.load(f)

summary_only = True
df = []
solution = Solution()
timer = []
correct = 0
for test_idx, data_point in enumerate(data):
    address = data_point["text"]

    ok = 0
    try:
        answer = data_point["result"]
        answer["province_normalized"] = normalize(answer["province"], same_province)
        answer["district_normalized"] = normalize(answer["district"], same_district)
        answer["ward_normalized"] = normalize(answer["ward"], same_ward)

        start = time.perf_counter_ns()
        print(address)
        result = solution.process(address)
        finish = time.perf_counter_ns()
        timer.append(finish - start)
        result["province_normalized"] = normalize(result["province"], same_province)
        result["district_normalized"] = normalize(result["district"], same_district)
        result["ward_normalized"] = normalize(result["ward"], same_ward)

        province_correct = int(answer["province_normalized"] == result["province_normalized"])
        district_correct = int(answer["district_normalized"] == result["district_normalized"])
        ward_correct = int(answer["ward_normalized"] == result["ward_normalized"])
        ok = province_correct + district_correct + ward_correct

        df.append([
            test_idx,
            address,
            answer["province"],
            result["province"],
            answer["province_normalized"],
            result["province_normalized"],
            province_correct,
            answer["district"],
            result["district"],
            answer["district_normalized"],
            result["district_normalized"],
            district_correct,
            answer["ward"],
            result["ward"],
            answer["ward_normalized"],
            result["ward_normalized"],
            ward_correct,
            ok,
            timer[-1] / 1_000_000_000,
        ])
        if debug and ok < 3:
            print()
            print("Original: " + address)
            if province_correct == 0:
                print(f"Province -> Result: '{result['province']}', Answer: '{answer['province']}'")
            if district_correct == 0:
                print(f"District -> Result: '{result['district']}', Answer: '{answer['district']}'")
            if ward_correct == 0:
                print(f"Ward -> Result: '{result['ward']}', Answer: '{answer['ward']}'")
    except Exception as e:
        print(f"{answer = }")
        print(f"{result = }")
        df.append([
            test_idx,
            address,
            answer["province"],
            "EXCEPTION",
            answer["province_normalized"],
            "EXCEPTION",
            0,
            answer["district"],
            "EXCEPTION",
            answer["district_normalized"],
            "EXCEPTION",
            0,
            answer["ward"],
            "EXCEPTION",
            answer["ward_normalized"],
            "EXCEPTION",
            0,
            0,
            0,
        ])
        # any failure count as a zero correct
        pass
    correct += ok

    if not summary_only:
        # responsive stuff
        print(f"Test {test_idx:5d}/{len(data):5d}")
        print(f"Correct: {ok}/3")
        print(f"Time Executed: {timer[-1] / 1_000_000_000:.4f}")

print(f"-" * 30)
total = len(data) * 3
score_scale_10 = round(correct / total * 10, 2)
if len(timer) == 0:
    timer = [0]
max_time_sec = round(max(timer) / 1_000_000_000, 4)
avg_time_sec = round((sum(timer) / len(timer)) / 1_000_000_000, 4)

df2 = pd.DataFrame(
    [[correct, total, score_scale_10, max_time_sec, avg_time_sec]],
    columns=['correct', 'total', 'score / 10', 'max_time_sec', 'avg_time_sec', ],
)

columns = [
    'ID',
    'text',
    'province',
    'province_student',
    'province_normalized',
    'province_student_normalized',
    'province_correct',
    'district',
    'district_student',
    'district_normalized',
    'district_student_normalized',
    'district_correct',
    'ward',
    'ward_student',
    'ward_normalized',
    'ward_student_normalized',
    'ward_correct',
    'total_correct',
    'time_sec',
]

df = pd.DataFrame(df)
df.columns = columns

print(df2)

if not debug:
    print(f'{TEAM_NAME = }')
    print(f'{EXCEL_FILE = }')

    with pd.ExcelWriter(EXCEL_FILE, engine='xlsxwriter') as writer:
        df2.to_excel(writer, index=False, sheet_name='summary')
        df.to_excel(writer, index=False, sheet_name='details')

print("Excel file saved successfully.")
# Out:
# ['q01', 'quận01', 'q1', 'quận1']
# ['q08', 'quận08', 'q8', 'quận8']
# ['q01', 'quận01', 'q1', 'quận1']
# ['q12', 'quận12']
# ['q01', 'quận01', 'q1', 'quận1']
# ['q10', 'quận10']
# ['q2', 'quận2', 'q02', 'quận02']
# ['q10', 'quận10']
# ['q6', 'quận6', 'q06', 'quận06']
# ['q6', 'quận6', 'q06', 'quận06']
# ['q11', 'quận11']
# ['q01', 'quận01', 'q1', 'quận1']
# ['p3', 'phường3', 'p03', 'phường03']
# ['p13', 'phường13']
# ['p08', 'phường08', 'p8', 'phường8']
# ['p05', 'phường05', 'p5', 'phường5']
# ['p13', 'phường13']
# ['p3', 'phường3', 'p03', 'phường03']
# ['p12', 'phường12']
# ['p14', 'phường14']
# ['p12', 'phường12']
# ['p04', 'phường04', 'p4', 'phường4']
# ['p07', 'phường07', 'p7', 'phường7']
# ['p04', 'phường04', 'p4', 'phường4']
# diênthạnh,tkhabnhhòa
# diênthạnh,tkhabnhhòa
# diênthạnh,tkhabnhhòa
# ('diênthạnh', 0, 9)
# ,,tkhabnhhòa
#
# Original: Diên Thạnh,,T Khabnh Hòa
# Normalized: diênthạnh,,tkhabnhhòa
# Result: {'province': 'Thanh Hóa', 'district': '', 'ward': 'Diên Thạnh'}
# ['q01', 'quận01', 'q1', 'quận1']
# ['q08', 'quận08', 'q8', 'quận8']
# ['q01', 'quận01', 'q1', 'quận1']
# ['q12', 'quận12']
# ['q01', 'quận01', 'q1', 'quận1']
# ['q10', 'quận10']
# ['q2', 'quận2', 'q02', 'quận02']
# ['q10', 'quận10']
# ['q6', 'quận6', 'q06', 'quận06']
# ['q6', 'quận6', 'q06', 'quận06']
# ['q11', 'quận11']
# ['q01', 'quận01', 'q1', 'quận1']
# ['p3', 'phường3', 'p03', 'phường03']
# ['p13', 'phường13']
# ['p08', 'phường08', 'p8', 'phường8']
# ['p05', 'phường05', 'p5', 'phường5']
# ['p13', 'phường13']
# ['p3', 'phường3', 'p03', 'phường03']
# ['p12', 'phường12']
# ['p14', 'phường14']
# ['p12', 'phường12']
# ['p04', 'phường04', 'p4', 'phường4']
# ['p07', 'phường07', 'p7', 'phường7']
# ['p04', 'phường04', 'p4', 'phường4']
# ttt,â,nb,ì,n,h,yênsơn,tuyênquang
# ('tuyênquang', 22, 32)
# ttt,â,nb,ì,n,h,yênsơn,,
# ('yênsơn', 15, 21)
# ttt,â,nb,ì,n,h,,,,
# ttt,â,nb,ì,n,h,,,,
# 357/28,ng-t-thuật,p1,q3,tphồchíminh
# ('hồchíminh', 26, 35)
# 357/28,ng-t-thuật,p1,q3,tp,
# 357/28,ng-t-thuật,p1,q3,tp,
# 357/28,ng-t-thuật,p1,q3,tp,
# 284dbisngvăngiáo,p3,mỹtho,tgiang
# 284dbisngvăngiáo,p3,mỹtho,tgiang
# ('mỹtho', 20, 25)
# 284dbisngvăngiáo,p3,,,tgiang
# ('p3', 17, 19)
# 284dbisngvăngiáo,,,,,tgiang
# nàlàngphúbình,chiêmhóa,tuyênquang
# ('tuyênquang', 23, 33)
# nàlàngphúbình,chiêmhóa,,
# ('chiêmhóa', 14, 22)
# nàlàngphúbình,,,,
# ('phúbình', 6, 13)
# nàlàng,,,,,
# 59/12ng-b-khiêm,đakaoquận1,tp,hồchíminh
# ('hồchíminh', 30, 39)
# 59/12ng-b-khiêm,đakaoquận1,tp,,
# ('quận1', 21, 26)
# 59/12ng-b-khiêm,đakao,,tp,,
# ('đakao', 16, 21)
# 59/12ng-b-khiêm,,,,tp,,
# 46/8ftrungchánh2trungchánh,hócmôn,tp,hồchíminh
# ('hồchíminh', 37, 46)
# 46/8ftrungchánh2trungchánh,hócmôn,tp,,
# ('hócmôn', 27, 33)
# 46/8ftrungchánh2trungchánh,,,tp,,
# ('trungchánh', 16, 26)
# 46/8ftrungchánh2,,,,tp,,
# t18,cẩmbình,cẩmphả,quảngninh
# ('quảngninh', 19, 28)
# t18,cẩmbình,cẩmphả,,
# ('cẩmphả', 12, 18)
# t18,cẩmbình,,,,
# ('cẩmbình', 4, 11)
# t18,,,,,,
# thanhlong,yênmỹhưngyên
# ('hưngyên', 15, 22)
# thanhlong,yênmỹ,
# ('yênmỹ', 10, 15)
# thanhlong,,,
# ('thanhlong', 0, 9)
# ,,,,
# d2,thạnhlợi,vĩnhthạnhcầnthơ
# ('cầnthơ', 21, 27)
# d2,thạnhlợi,vĩnhthạnh,
# ('vĩnhthạnh', 12, 21)
# d2,thạnhlợi,,,
# ('thạnhlợi', 3, 11)
# d2,,,,,
# cổlũyhảiba,hảilăng,quảngtrị
# ('quảngtrị', 19, 27)
# cổlũyhảiba,hảilăng,,
# ('hảilăng', 11, 18)
# cổlũyhảiba,,,,
# ('hảiba', 5, 10)
# cổlũy,,,,,
# 4,dươngminhchâu,tâyninh
# ('tâyninh', 16, 23)
# 4,dươngminhchâu,,
# ('dươngminhchâu', 2, 15)
# 4,,,,
# 4,,,,
# 3,trảngdài,thànhphốbiênhòa,đồngnai
# ('đồngnai', 27, 34)
# 3,trảngdài,thànhphốbiênhòa,,
# ('biênhòa', 19, 26)
# 3,trảngdài,thànhphố,,,
# ('trảngdài', 2, 10)
# 3,,,thànhphố,,,
# sốnhà38,tổ9tôhiệu,thànhphốsơnla,sơnla
# ('sơnla', 32, 37)
# sốnhà38,tổ9tôhiệu,thànhphốsơnla,,
# ('sơnla', 26, 31)
# sốnhà38,tổ9tôhiệu,thànhphố,,,
# ('tôhiệu', 11, 17)
# sốnhà38,tổ9,,thànhphố,,,
# chf1614-hh2-khuđtmdươngnộiyênnghĩahàdônghyànội
# chf1614-hh2-khuđtmdươngnộiyênnghĩahàdônghyànội
# chf1614-hh2-khuđtmdươngnộiyênnghĩahàdônghyànội
# ('yênnghĩa', 26, 34)
# chf1614-hh2-khuđtmdươngnội,hàdônghyànội
# khu3suốihoa,thànhphốbắcninh,bắcninh
# ('bắcninh', 28, 35)
# khu3suốihoa,thànhphốbắcninh,,
# ('bắcninh', 20, 27)
# khu3suốihoa,thànhphố,,,
# ('suốihoa', 4, 11)
# khu3,,thànhphố,,,
# phúlộcphúthạnh,phútân,angiang
# ('angiang', 22, 29)
# phúlộcphúthạnh,phútân,,
# ('phútân', 15, 21)
# phúlộcphúthạnh,,,,
# ('phúthạnh', 6, 14)
# phúlộc,,,,,
# nguyễnkhuyến,vĩnhtrụ,lýnhân,hànam
# ('hànam', 28, 33)
# nguyễnkhuyến,vĩnhtrụ,lýnhân,,
# ('lýnhân', 21, 27)
# nguyễnkhuyến,vĩnhtrụ,,,,
# ('vĩnhtrụ', 13, 20)
# nguyễnkhuyến,,,,,,
# namchínhtiềnhải,tháibình
# ('tháibình', 16, 24)
# namchínhtiềnhải,,
# ('tiềnhải', 8, 15)
# namchính,,,
# ('namchính', 0, 8)
# ,,,,
# đáhànghiệpthạnh,gòdầu,tâyninh
# ('tâyninh', 22, 29)
# đáhànghiệpthạnh,gòdầu,,
# ('gòdầu', 16, 21)
# đáhànghiệpthạnh,,,,
# ('hiệpthạnh', 6, 15)
# đáhàng,,,,,
# 371/11thọaingọchầuhiệptân,tânphú,tp,hồchíminh
# ('hồchíminh', 36, 45)
# 371/11thọaingọchầuhiệptân,tânphú,tp,,
# ('tânphú', 26, 32)
# 371/11thọaingọchầuhiệptân,,,tp,,
# ('hiệptân', 18, 25)
# 371/11thọaingọchầu,,,,tp,,
# số93,9,hairiêng,sônghinh,phúyên
# ('phúyên', 25, 31)
# số93,9,hairiêng,sônghinh,,
# ('sônghinh', 16, 24)
# số93,9,hairiêng,,,,
# ('hairiêng', 7, 15)
# số93,9,,,,,,
# tổdânphố3,chưprông,chưprông,gialai
# ('gialai', 28, 34)
# tổdânphố3,chưprông,chưprông,,
# ('chưprông', 19, 27)
# tổdânphố3,chưprông,,,,
# ('chưprông', 10, 18)
# tổdânphố3,,,,,,
# minhđạo,tiêndu,bắcninh
# ('bắcninh', 15, 22)
# minhđạo,tiêndu,,
# ('tiêndu', 8, 14)
# minhđạo,,,,
# ('minhđạo', 0, 7)
# ,,,,,
# bồngkhê,concuông,nghệan
# ('nghệan', 17, 23)
# bồngkhê,concuông,,
# ('concuông', 8, 16)
# bồngkhê,,,,
# ('bồngkhê', 0, 7)
# ,,,,,
# thôn16cưprông,eakar,đắklắk
# ('đắklắk', 20, 26)
# thôn16cưprông,eakar,,
# ('eakar', 14, 19)
# thôn16cưprông,,,,
# ('cưprông', 6, 13)
# thôn16,,,,,
# số259/54/8,tổ28,1,longbìnhtân,biênhòa,đồngnai
# ('đồngnai', 38, 45)
# số259/54/8,tổ28,1,longbìnhtân,biênhòa,,
# ('biênhòa', 30, 37)
# số259/54/8,tổ28,1,longbìnhtân,,,,
# ('longbìnhtân', 18, 29)
# số259/54/8,tổ28,1,,,,,,
# phápngỡ,vĩnhhòavĩnhlộc,thanhhóa
# ('thanhhóa', 23, 31)
# phápngỡ,vĩnhhòavĩnhlộc,,
# ('vĩnhlộc', 15, 22)
# phápngỡ,vĩnhhòa,,,
# ('vĩnhhòa', 8, 15)
# phápngỡ,,,,,
# thônchuabìnhminh,thanhoai,hànội
# ('hànội', 26, 31)
# thônchuabìnhminh,thanhoai,,
# ('thanhoai', 17, 25)
# thônchuabìnhminh,,,,
# ('bìnhminh', 8, 16)
# thônchua,,,,,
# tiểukhu3,bahàng,phổyên,tháinguyên
# ('tháinguyên', 23, 33)
# tiểukhu3,bahàng,phổyên,,
# ('phổyên', 16, 22)
# tiểukhu3,bahàng,,,,
# tiểukhu3,bahàng,,,,
# xóm2,hưngmỹ,hưngnguyên,nghệan
# ('nghệan', 23, 29)
# xóm2,hưngmỹ,hưngnguyên,,
# ('hưngnguyên', 12, 22)
# xóm2,hưngmỹ,,,,
# ('hưngmỹ', 5, 11)
# xóm2,,,,,,
# bươnghạnam,quỳnhngọcquỳnhphụ,tháibình
# ('tháibình', 29, 37)
# bươnghạnam,quỳnhngọcquỳnhphụ,,
# ('quỳnhphụ', 20, 28)
# bươnghạnam,quỳnhngọc,,,
# ('quỳnhngọc', 11, 20)
# bươnghạnam,,,,,
# nậmchasìnhổ,laichâu
# ('laichâu', 12, 19)
# nậmchasìnhổ,,
# nậmchasìnhổ,,
# ('nậmcha', 0, 6)
# ,sìnhổ,,
# tdphạ10,tâytựubắctừliêm,hànội
# ('hànội', 24, 29)
# tdphạ10,tâytựubắctừliêm,,
# ('bắctừliêm', 14, 23)
# tdphạ10,tâytựu,,,
# ('tâytựu', 8, 14)
# tdphạ10,,,,,
# p,nghihương,cửalò,nghệan
# ('nghệan', 18, 24)
# p,nghihương,cửalò,,
# ('cửalò', 12, 17)
# p,nghihương,,,,
# ('nghihương', 2, 11)
# p,,,,,,
# hoằnganhthànhphốthanhhóa,thanhhóa
# ('thanhhóa', 25, 33)
# hoằnganhthànhphốthanhhóa,,
# ('thanhhóa', 16, 24)
# hoằnganhthànhphố,,,
# ('hoằnganh', 0, 8)
# ,thànhphố,,,
# ấpphúhữuhữuđịnh,châuthành,bếntre
# ('bếntre', 26, 32)
# ấpphúhữuhữuđịnh,châuthành,,
# ('châuthành', 16, 25)
# ấpphúhữuhữuđịnh,,,,
# ('hữuđịnh', 8, 15)
# ấpphúhữu,,,,,
# phườngyênthanh,thànhphốuôngbí,quảngninh
# ('quảngninh', 30, 39)
# phườngyênthanh,thànhphốuôngbí,,
# ('uôngbí', 23, 29)
# phườngyênthanh,thànhphố,,,
# ('yênthanh', 6, 14)
# phường,,thànhphố,,,
# khóm1ttcànglong,cànglong,tràvinh
# ('tràvinh', 25, 32)
# khóm1ttcànglong,cànglong,,
# ('cànglong', 16, 24)
# khóm1ttcànglong,,,,
# ('cànglong', 7, 15)
# khóm1tt,,,,,
# 1b,panphú,txthuậnan,bìnhdương
# ('bìnhdương', 20, 29)
# 1b,panphú,txthuậnan,,
# ('thuậnan', 12, 19)
# 1b,panphú,tx,,,
# ('anphú', 4, 9)
# 1b,p,,tx,,,
# thônxuânlũngbìnhtrung,caolộc,lạngsơn
# ('lạngsơn', 29, 36)
# thônxuânlũngbìnhtrung,caolộc,,
# ('caolộc', 22, 28)
# thônxuânlũngbìnhtrung,,,,
# ('bìnhtrung', 12, 21)
# thônxuânlũng,,,,,
# phườnghòacườngnam,quậnhảichâu,thànhphốđànẵng
# ('đànẵng', 38, 44)
# phườnghòacườngnam,quậnhảichâu,thànhphố,
# ('hảichâu', 22, 29)
# phườnghòacườngnam,quận,,thànhphố,
# ('hòacườngnam', 6, 17)
# phường,,quận,,thànhphố,
# tt,phùmỹphùmỹ,bìnhđịnh
# ('bìnhđịnh', 14, 22)
# tt,phùmỹphùmỹ,,
# ('phùmỹ', 8, 13)
# tt,phùmỹ,,,
# ('phùmỹ', 3, 8)
# tt,,,,,
# đôxá,dânlực,triệusơn,thanhhóa
# ('thanhhóa', 21, 29)
# đôxá,dânlực,triệusơn,,
# ('triệusơn', 12, 20)
# đôxá,dânlực,,,,
# ('dânlực', 5, 11)
# đôxá,,,,,,
# 154/4/81nguyễn-phúcchu,p15,tb,tp,hồchíminh
# ('hồchíminh', 33, 42)
# 154/4/81nguyễn-phúcchu,p15,tb,tp,,
# 154/4/81nguyễn-phúcchu,p15,tb,tp,,
# 154/4/81nguyễn-phúcchu,p15,tb,tp,,
# caodương,thanhoai,thànhphốhànội
# ('hànội', 26, 31)
# caodương,thanhoai,thànhphố,
# ('thanhoai', 9, 17)
# caodương,,,thànhphố,
# ('caodương', 0, 8)
# ,,,,thànhphố,
# tổ8,ấpanbìnhminhhòa,châuthành,kiêngiang
# ('kiêngiang', 30, 39)
# tổ8,ấpanbìnhminhhòa,châuthành,,
# ('châuthành', 20, 29)
# tổ8,ấpanbìnhminhhòa,,,,
# ('minhhòa', 12, 19)
# tổ8,ấpanbình,,,,,
# khuvực1ttđứchòa,đứchòa,longan
# ('longan', 23, 29)
# khuvực1ttđứchòa,đứchòa,,
# ('đứchòa', 16, 22)
# khuvực1ttđứchòa,,,,
# ('đứchòa', 9, 15)
# khuvực1tt,,,,,
# phườngđịnhcông,quậnhòangmai,thànhphốhànội
# ('hànội', 36, 41)
# phườngđịnhcông,quậnhòangmai,thànhphố,
# ('hòangmai', 19, 27)
# phườngđịnhcông,quận,,thànhphố,
# ('địnhcông', 6, 14)
# phường,,quận,,thànhphố,
# khóm1,tambình,vĩnhlong
# ('vĩnhlong', 14, 22)
# khóm1,tambình,,
# ('tambình', 6, 13)
# khóm1,,,,
# khóm1,,,,
# mêlinhlâmhà,lâmđồng
# ('lâmđồng', 12, 19)
# mêlinhlâmhà,,
# ('lâmhà', 6, 11)
# mêlinh,,,
# ('mêlinh', 0, 6)
# ,,,,
# đứclongtp,phanthiết,bìnhthuận
# ('bìnhthuận', 20, 29)
# đứclongtp,phanthiết,,
# ('phanthiết', 10, 19)
# đứclongtp,,,,
# ('đứclong', 0, 7)
# ,tp,,,,
# phốđứcsơn,ttbútsơn,hoằnghóa,thanhhóa
# ('thanhhóa', 28, 36)
# phốđứcsơn,ttbútsơn,hoằnghóa,,
# ('hoằnghóa', 19, 27)
# phốđứcsơn,ttbútsơn,,,,
# ('bútsơn', 12, 18)
# phốđứcsơn,tt,,,,,
# tổ1,phútrungpanlộc,txbìnhlong,bìnhphước
# ('bìnhphước', 30, 39)
# tổ1,phútrungpanlộc,txbìnhlong,,
# ('bìnhlong', 21, 29)
# tổ1,phútrungpanlộc,tx,,,
# ('anlộc', 13, 18)
# tổ1,phútrungp,,tx,,,
# tháihòa,tháithụy,tháibình
# ('tháibình', 17, 25)
# tháihòa,tháithụy,,
# ('tháithụy', 8, 16)
# tháihòa,,,,
# ('tháihòa', 0, 7)
# ,,,,,
# thanhhòa,cailậy,tiềngiang
# ('tiềngiang', 16, 25)
# thanhhòa,cailậy,,
# ('cailậy', 9, 15)
# thanhhòa,,,,
# ('thanhhòa', 0, 8)
# ,,,,,
# thôn3sơnhải,quỳnhlưu,nghệan
# ('nghệan', 21, 27)
# thôn3sơnhải,quỳnhlưu,,
# ('quỳnhlưu', 12, 20)
# thôn3sơnhải,,,,
# ('sơnhải', 5, 11)
# thôn3,,,,,
# thônthànhbắc,quảngthành,tpthanhhóa,thanhhóa
# ('thanhhóa', 35, 43)
# thônthànhbắc,quảngthành,tpthanhhóa,,
# ('thanhhóa', 26, 34)
# thônthànhbắc,quảngthành,tp,,,
# ('quảngthành', 13, 23)
# thônthànhbắc,,,tp,,,
# chùahà,địnhtrung,vĩnhyênvĩnhphúc
# ('vĩnhphúc', 24, 32)
# chùahà,địnhtrung,vĩnhyên,
# ('vĩnhyên', 17, 24)
# chùahà,địnhtrung,,,
# ('địnhtrung', 7, 16)
# chùahà,,,,,
# t,phướctrạch2eaphê,krôngpăc,đắklắk
# ('đắklắk', 28, 34)
# t,phướctrạch2eaphê,krôngpăc,,
# t,phướctrạch2eaphê,krôngpăc,,
# ('eaphê', 13, 18)
# t,phướctrạch2,,krôngpăc,,
# lươnglỗ,thanhba,phúthọ
# ('phúthọ', 16, 22)
# lươnglỗ,thanhba,,
# ('thanhba', 8, 15)
# lươnglỗ,,,,
# ('lươnglỗ', 0, 7)
# ,,,,,
# khangthọhưnghoằngđức,hoằnghóa,thanhhóa
# ('thanhhóa', 30, 38)
# khangthọhưnghoằngđức,hoằnghóa,,
# ('hoằnghóa', 21, 29)
# khangthọhưnghoằngđức,,,,
# ('hoằngđức', 12, 20)
# khangthọhưng,,,,,
# namhảinamtrực-namđịnh
# ('namđịnh', 14, 21)
# namhảinamtrực-,
# ('namtrực', 6, 13)
# namhải,-,
# ('namhải', 0, 6)
# ,,-,
# 489/24a/18huỳnhvănbánhphường13,phúnhuận,tp,hồchíminh
# ('hồchíminh', 43, 52)
# 489/24a/18huỳnhvănbánhphường13,phúnhuận,tp,,
# ('phúnhuận', 31, 39)
# 489/24a/18huỳnhvănbánhphường13,,,tp,,
# ('phường13', 22, 30)
# 489/24a/18huỳnhvănbánh,,,,tp,,
# 285b/1abìnhgĩaphường8,vũngtàu,bàrịa-vũngtàu
# ('bàrịa-vũngtàu', 30, 43)
# 285b/1abìnhgĩaphường8,vũngtàu,,
# ('vũngtàu', 22, 29)
# 285b/1abìnhgĩaphường8,,,,
# ('phường8', 14, 21)
# 285b/1abìnhgĩa,,,,,
# mỹhòa,mỹlong,hcailậy,tiềngiang
# ('tiềngiang', 21, 30)
# mỹhòa,mỹlong,hcailậy,,
# ('cailậy', 14, 20)
# mỹhòa,mỹlong,h,,,
# ('mỹlong', 6, 12)
# mỹhòa,,,h,,,
# thớihòaa,cờđỏ,cờđỏ,cầnthơ
# ('cầnthơ', 19, 25)
# thớihòaa,cờđỏ,cờđỏ,,
# ('cờđỏ', 14, 18)
# thớihòaa,cờđỏ,,,,
# ('cờđỏ', 9, 13)
# thớihòaa,,,,,,
# minhlãng,vũthư,tháibình
# ('tháibình', 15, 23)
# minhlãng,vũthư,,
# ('vũthư', 9, 14)
# minhlãng,,,,
# ('minhlãng', 0, 8)
# ,,,,,
# bộđầuthốngnhất,thườngtín,hànội
# ('hànội', 25, 30)
# bộđầuthốngnhất,thườngtín,,
# ('thườngtín', 15, 24)
# bộđầuthốngnhất,,,,
# ('thốngnhất', 5, 14)
# bộđầu,,,,,
# tânbình,nhưxuân,thanhhóa
# ('thanhhóa', 16, 24)
# tânbình,nhưxuân,,
# ('nhưxuân', 8, 15)
# tânbình,,,,
# ('tânbình', 0, 7)
# ,,,,,
# phố2,vângiangthànhphốninhbình,ninhbình
# ('ninhbình', 30, 38)
# phố2,vângiangthànhphốninhbình,,
# ('ninhbình', 21, 29)
# phố2,vângiangthànhphố,,,
# ('vângiang', 5, 13)
# phố2,,thànhphố,,,
# thôn1quảngbị,chươngmỹ,hànội
# ('hànội', 22, 27)
# thôn1quảngbị,chươngmỹ,,
# ('chươngmỹ', 13, 21)
# thôn1quảngbị,,,,
# ('quảngbị', 5, 12)
# thôn1,,,,,
# tânminh,sócsơn,thànhphốhànội
# ('hànội', 23, 28)
# tânminh,sócsơn,thànhphố,
# ('sócsơn', 8, 14)
# tânminh,,,thànhphố,
# ('tânminh', 0, 7)
# ,,,,thànhphố,
# tổ11sàiđồng,longbiên,hànội
# ('hànội', 21, 26)
# tổ11sàiđồng,longbiên,,
# ('longbiên', 12, 20)
# tổ11sàiđồng,,,,
# ('sàiđồng', 4, 11)
# tổ11,,,,,
# 4248ct12cđtmk/văn-k/lũđạikim,hòangmai,hànội
# ('hànội', 38, 43)
# 4248ct12cđtmk/văn-k/lũđạikim,hòangmai,,
# ('hòangmai', 29, 37)
# 4248ct12cđtmk/văn-k/lũđạikim,,,,
# ('đạikim', 22, 28)
# 4248ct12cđtmk/văn-k/lũ,,,,,
# phướctrung,đấtđỏ,đấtđỏ,bàrịa-vũngtàu
# ('bàrịa-vũngtàu', 23, 36)
# phướctrung,đấtđỏ,đấtđỏ,,
# ('đấtđỏ', 17, 22)
# phướctrung,đấtđỏ,,,,
# ('đấtđỏ', 11, 16)
# phướctrung,,,,,,
# 55/30nguyễn-thượnghiền,p5,bt,tp,hồchíminh
# ('hồchíminh', 32, 41)
# 55/30nguyễn-thượnghiền,p5,bt,tp,,
# 55/30nguyễn-thượnghiền,p5,bt,tp,,
# ('p5', 23, 25)
# 55/30nguyễn-thượnghiền,,,bt,tp,,
# 290tùngthiện-vương,p13,quận8,tp,hồchíminh
# ('hồchíminh', 32, 41)
# 290tùngthiện-vương,p13,quận8,tp,,
# ('quận8', 23, 28)
# 290tùngthiện-vương,p13,,,tp,,
# ('p13', 19, 22)
# 290tùngthiện-vương,,,,,tp,,
# tổ5a2,5tt,trảngbom,trảngbom,đồngnai
# ('đồngnai', 28, 35)
# tổ5a2,5tt,trảngbom,trảngbom,,
# ('trảngbom', 19, 27)
# tổ5a2,5tt,trảngbom,,,,
# ('trảngbom', 10, 18)
# tổ5a2,5tt,,,,,,
# 8trịnhvăncấnpc-ô-lãnh,q1,tp,hồchíminh
# ('hồchíminh', 28, 37)
# 8trịnhvăncấnpc-ô-lãnh,q1,tp,,
# ('q1', 22, 24)
# 8trịnhvăncấnpc-ô-lãnh,,,tp,,
# 8trịnhvăncấnpc-ô-lãnh,,,tp,,
# thônđồnglựchòanglâu,tamdương,vĩnhphúc
# ('vĩnhphúc', 29, 37)
# thônđồnglựchòanglâu,tamdương,,
# ('tamdương', 20, 28)
# thônđồnglựchòanglâu,,,,
# ('hòanglâu', 11, 19)
# thônđồnglực,,,,,
# tháihòa,hợpđồngchươngmỹ,hànội
# ('hànội', 24, 29)
# tháihòa,hợpđồngchươngmỹ,,
# ('chươngmỹ', 15, 23)
# tháihòa,hợpđồng,,,
# ('hợpđồng', 8, 15)
# tháihòa,,,,,
# đồngtrạch,bốtrạchquảngbình
# ('quảngbình', 17, 26)
# đồngtrạch,bốtrạch,
# ('bốtrạch', 10, 17)
# đồngtrạch,,,
# ('đồngtrạch', 0, 9)
# ,,,,
# thônyếnthạchxá-thạchthất-hànội
# ('hànội', 25, 30)
# thônyếnthạchxá-thạchthất-,
# ('thạchthất', 15, 24)
# thônyếnthạchxá-,-,
# ('thạchxá', 7, 14)
# thônyến,-,-,
# tổ17cụm3phúthượng,tâyhồ,hànội
# ('hànội', 24, 29)
# tổ17cụm3phúthượng,tâyhồ,,
# ('tâyhồ', 18, 23)
# tổ17cụm3phúthượng,,,,
# ('phúthượng', 8, 17)
# tổ17cụm3,,,,,
# bảnugiahuổiluông,phongthổ,laichâu
# ('laichâu', 26, 33)
# bảnugiahuổiluông,phongthổ,,
# ('phongthổ', 17, 25)
# bảnugiahuổiluông,,,,
# ('huổiluông', 7, 16)
# bảnugia,,,,,
# namtân,ttthuậnnam,hàmthuậnbắc,bìnhthuận
# ('bìnhthuận', 30, 39)
# namtân,ttthuậnnam,hàmthuậnbắc,,
# namtân,ttthuậnnam,hàmthuậnbắc,,
# namtân,ttthuậnnam,hàmthuậnbắc,,
# 2dãycngõ16ngôquyền,tổ14,quangtrung,hàđông,hànội
# ('hànội', 42, 47)
# 2dãycngõ16ngôquyền,tổ14,quangtrung,hàđông,,
# ('hàđông', 35, 41)
# 2dãycngõ16ngôquyền,tổ14,quangtrung,,,,
# ('quangtrung', 24, 34)
# 2dãycngõ16ngôquyền,tổ14,,,,,,
# sơnhànhoquan,ninhbình
# ('ninhbình', 13, 21)
# sơnhànhoquan,,
# ('nhoquan', 5, 12)
# sơnhà,,,
# ('sơnhà', 0, 5)
# ,,,,
# 3/107ngõquỳnhthanhnhàn,haibàtrưng,hànội
# ('hànội', 34, 39)
# 3/107ngõquỳnhthanhnhàn,haibàtrưng,,
# ('haibàtrưng', 23, 33)
# 3/107ngõquỳnhthanhnhàn,,,,
# ('thanhnhàn', 13, 22)
# 3/107ngõquỳnh,,,,,
# hànggònhànggòn,txlongkhánh,đồngnai
# ('đồngnai', 27, 34)
# hànggònhànggòn,txlongkhánh,,
# ('longkhánh', 17, 26)
# hànggònhànggòn,tx,,,
# ('hànggòn', 7, 14)
# hànggòn,,tx,,,
# nguyênbình,tĩnhgia,thanhhóa
# ('thanhhóa', 19, 27)
# nguyênbình,tĩnhgia,,
# ('tĩnhgia', 11, 18)
# nguyênbình,,,,
# ('nguyênbình', 0, 10)
# ,,,,,
# cụm5,ngọctảo,phúcthọhànội
# ('hànội', 20, 25)
# cụm5,ngọctảo,phúcthọ,
# ('phúcthọ', 13, 20)
# cụm5,ngọctảo,,,
# ('ngọctảo', 5, 12)
# cụm5,,,,,
# hoằngminh,hoằnghóathanhhóa
# ('thanhhóa', 18, 26)
# hoằngminh,hoằnghóa,
# ('hoằnghóa', 10, 18)
# hoằngminh,,,
# ('hoằngminh', 0, 9)
# ,,,,
# châuthạnhchâuphúa,châuđốc,angiang
# ('angiang', 26, 33)
# châuthạnhchâuphúa,châuđốc,,
# ('châuđốc', 18, 25)
# châuthạnhchâuphúa,,,,
# ('châuphúa', 9, 17)
# châuthạnh,,,,,
# liênbình,hảibìnhtĩnhgia,thanhhóa
# ('thanhhóa', 24, 32)
# liênbình,hảibìnhtĩnhgia,,
# ('tĩnhgia', 16, 23)
# liênbình,hảibình,,,
# ('hảibình', 9, 16)
# liênbình,,,,,
# longbình1,anhải,ninhphước,ninhthuận
# ('ninhthuận', 26, 35)
# longbình1,anhải,ninhphước,,
# ('ninhphước', 16, 25)
# longbình1,anhải,,,,
# ('anhải', 10, 15)
# longbình1,,,,,,
# ấp17longtrung,cailậy,tiềngiang
# ('tiềngiang', 21, 30)
# ấp17longtrung,cailậy,,
# ('cailậy', 14, 20)
# ấp17longtrung,,,,
# ('longtrung', 4, 13)
# ấp17,,,,,
# 249,2,tânmai,biênhòa,đồngnai
# ('đồngnai', 21, 28)
# 249,2,tânmai,biênhòa,,
# ('biênhòa', 13, 20)
# 249,2,tânmai,,,,
# ('tânmai', 6, 12)
# 249,2,,,,,,
# sơnthủy,lệthủyquảngbình
# ('quảngbình', 14, 23)
# sơnthủy,lệthủy,
# ('lệthủy', 8, 14)
# sơnthủy,,,
# ('sơnthủy', 0, 7)
# ,,,,
# 02túxương,đôngthọthànhphốthanhhóa,thanhhóa
# ('thanhhóa', 34, 42)
# 02túxương,đôngthọthànhphốthanhhóa,,
# ('thanhhóa', 25, 33)
# 02túxương,đôngthọthànhphố,,,
# ('đôngthọ', 10, 17)
# 02túxương,,thànhphố,,,
# tântrungtânthành,tânchâu,tâyninh
# ('tâyninh', 25, 32)
# tântrungtânthành,tânchâu,,
# ('tânchâu', 17, 24)
# tântrungtânthành,,,,
# ('tânthành', 8, 16)
# tântrung,,,,,
# số43/7nguyễnhuệ,psaođỏ,txchílinh,hảidương
# ('hảidương', 33, 41)
# số43/7nguyễnhuệ,psaođỏ,txchílinh,,
# ('chílinh', 25, 32)
# số43/7nguyễnhuệ,psaođỏ,tx,,,
# ('saođỏ', 17, 22)
# số43/7nguyễnhuệ,p,,tx,,,
# 24/98c,phốhữunghịxuânkhanh,sơntây,hànội
# ('hànội', 34, 39)
# 24/98c,phốhữunghịxuânkhanh,sơntây,,
# ('sơntây', 27, 33)
# 24/98c,phốhữunghịxuânkhanh,,,,
# ('xuânkhanh', 17, 26)
# 24/98c,phốhữunghị,,,,,
# tổ2,2,phườnglongthủy,phướclong,bìnhphước
# ('bìnhphước', 31, 40)
# tổ2,2,phườnglongthủy,phướclong,,
# ('phướclong', 21, 30)
# tổ2,2,phườnglongthủy,,,,
# ('longthủy', 12, 20)
# tổ2,2,phường,,,,,
# hàtânhưnghà,tânhưng,longan
# ('longan', 20, 26)
# hàtânhưnghà,tânhưng,,
# ('tânhưng', 12, 19)
# hàtânhưnghà,,,,
# ('hưnghà', 5, 11)
# hàtân,,,,,
# ngọcchi,vĩnhngọcđônganh,hànội
# ('hànội', 24, 29)
# ngọcchi,vĩnhngọcđônganh,,
# ('đônganh', 16, 23)
# ngọcchi,vĩnhngọc,,,
# ('vĩnhngọc', 8, 16)
# ngọcchi,,,,,
# 55/21/1,2,thớianquận12,tp,hồchíminh
# ('hồchíminh', 26, 35)
# 55/21/1,2,thớianquận12,tp,,
# ('quận12', 16, 22)
# 55/21/1,2,thớian,,tp,,
# ('thớian', 10, 16)
# 55/21/1,2,,,,tp,,
# thạchbình,thạchthànhthanhhóa
# ('thanhhóa', 20, 28)
# thạchbình,thạchthành,
# ('thạchthành', 10, 20)
# thạchbình,,,
# ('thạchbình', 0, 9)
# ,,,,
# -khubchuhòa,việthhiphúthọ
# ('phúthọ', 19, 25)
# -khubchuhòa,việthhi,
# -khubchuhòa,việthhi,
# -khubchuhòa,việthhi,
# thônam,xuânhương,lạnggiang,bắcgiang
# ('bắcgiang', 27, 35)
# thônam,xuânhương,lạnggiang,,
# ('lạnggiang', 17, 26)
# thônam,xuânhương,,,,
# ('xuânhương', 7, 16)
# thônam,,,,,,
# số7/q3,i,phườnglongbìnhtân,tpbiênhòa,đồngnai
# ('đồngnai', 37, 44)
# số7/q3,i,phườnglongbìnhtân,tpbiênhòa,,
# ('biênhòa', 29, 36)
# số7/q3,i,phườnglongbìnhtân,tp,,,
# ('longbìnhtân', 15, 26)
# số7/q3,i,phường,,tp,,,
# khu1,trunggiáp,phùninh,phúthọ
# ('phúthọ', 23, 29)
# khu1,trunggiáp,phùninh,,
# ('phùninh', 15, 22)
# khu1,trunggiáp,,,,
# ('trunggiáp', 5, 14)
# khu1,,,,,,
# a:12a21blockac/cbca,pankhánh,tpthủđức,tp,hcm
# ('hcm', 41, 44)
# a:12a21blockac/cbca,pankhánh,tpthủđức,tp,,
# ('thủđức', 31, 37)
# a:12a21blockac/cbca,pankhánh,tp,,tp,,
# a:12a21blockac/cbca,pankhánh,tp,,tp,,
# l10c12hẻm90,ng,bỉnhkhiêm,tp,rạchgiá,kiêngiang
# ('kiêngiang', 36, 45)
# l10c12hẻm90,ng,bỉnhkhiêm,tp,rạchgiá,,
# l10c12hẻm90,ng,bỉnhkhiêm,tp,rạchgiá,,
# l10c12hẻm90,ng,bỉnhkhiêm,tp,rạchgiá,,
# thônlýviênbắclý,hiệphòa,bắcgiang
# ('bắcgiang', 24, 32)
# thônlýviênbắclý,hiệphòa,,
# ('hiệphòa', 16, 23)
# thônlýviênbắclý,,,,
# ('bắclý', 10, 15)
# thônlýviên,,,,,
# 51phạmngũlão,lêlợisơntây,hànội
# ('hànội', 25, 30)
# 51phạmngũlão,lêlợisơntây,,
# ('sơntây', 18, 24)
# 51phạmngũlão,lêlợi,,,
# ('lêlợi', 13, 18)
# 51phạmngũlão,,,,,
# 107lêsaophúthạnh,tânphú,tp,hồchíminh
# ('hồchíminh', 27, 36)
# 107lêsaophúthạnh,tânphú,tp,,
# ('tânphú', 17, 23)
# 107lêsaophúthạnh,,,tp,,
# ('phúthạnh', 8, 16)
# 107lêsao,,,,tp,,
# mỹphú5tườnglộc,tambình,vĩnhlong
# ('vĩnhlong', 23, 31)
# mỹphú5tườnglộc,tambình,,
# ('tambình', 15, 22)
# mỹphú5tườnglộc,,,,
# ('tườnglộc', 6, 14)
# mỹphú5,,,,,
# thônmùi,bíchhòathanhoai,hànội
# ('hànội', 24, 29)
# thônmùi,bíchhòathanhoai,,
# ('thanhoai', 15, 23)
# thônmùi,bíchhòa,,,
# ('bíchhòa', 8, 15)
# thônmùi,,,,,
# thôn2suốirao,châuđức,bàrịa-vũngtàu
# ('bàrịa-vũngtàu', 21, 34)
# thôn2suốirao,châuđức,,
# ('châuđức', 13, 20)
# thôn2suốirao,,,,
# ('suốirao', 5, 12)
# thôn2,,,,,
# p,minhxuântp,tuyênquang,tuyênquang
# ('tuyênquang', 24, 34)
# p,minhxuântp,tuyênquang,,
# ('tuyênquang', 13, 23)
# p,minhxuântp,,,,
# ('minhxuân', 2, 10)
# p,,tp,,,,
# longbình,anhải,ninhphước,ninhthuận
# ('ninhthuận', 25, 34)
# longbình,anhải,ninhphước,,
# ('ninhphước', 15, 24)
# longbình,anhải,,,,
# ('anhải', 9, 14)
# longbình,,,,,,
# 145blocka2,themansion,đs7,kdc13e,ấp5,pp,bc,tphcm
# ('hcm', 45, 48)
# 145blocka2,themansion,đs7,kdc13e,ấp5,pp,bc,tp,
# 145blocka2,themansion,đs7,kdc13e,ấp5,pp,bc,tp,
# ('p5', 34, 36)
# 145blocka2,themansion,đs7,kdc13e,ấ,,pp,bc,tp,
# yênsơn,lụcnam,bắcgiang
# ('bắcgiang', 14, 22)
# yênsơn,lụcnam,,
# ('lụcnam', 7, 13)
# yênsơn,,,,
# ('yênsơn', 0, 6)
# ,,,,,
# 161/18acôgiang,côgiangquận1,tp,hồchíminh
# ('hồchíminh', 31, 40)
# 161/18acôgiang,côgiangquận1,tp,,
# ('quận1', 22, 27)
# 161/18acôgiang,côgiang,,tp,,
# ('côgiang', 15, 22)
# 161/18acôgiang,,,,tp,,
# tânthắngtânanhội,mangthít,vĩnhlong
# ('vĩnhlong', 26, 34)
# tânthắngtânanhội,mangthít,,
# ('mangthít', 17, 25)
# tânthắngtânanhội,,,,
# ('tânanhội', 8, 16)
# tânthắng,,,,,
# thôn6,namchính,đứclinh,bìnhthuận
# ('bìnhthuận', 23, 32)
# thôn6,namchính,đứclinh,,
# ('đứclinh', 15, 22)
# thôn6,namchính,,,,
# ('namchính', 6, 14)
# thôn6,,,,,,
# phốtânmỹ,me,giaviễn,ninhbình
# ('ninhbình', 20, 28)
# phốtânmỹ,me,giaviễn,,
# ('giaviễn', 12, 19)
# phốtânmỹ,me,,,,
# ('me', 9, 11)
# phốtânmỹ,,,,,,
# pphanthiết,tuyênquang,tuyênquang
# ('tuyênquang', 22, 32)
# pphanthiết,tuyênquang,,
# ('tuyênquang', 11, 21)
# pphanthiết,,,,
# ('phanthiết', 1, 10)
# p,,,,,
# trungmônyênsơn-tuyênquang
# ('tuyênquang', 15, 25)
# trungmônyênsơn-,
# ('yênsơn', 8, 14)
# trungmôn,-,
# ('trungmôn', 0, 8)
# ,,-,
# 31bsưvạnhạnh,phường3quận10,tp,hồchíminh
# ('hồchíminh', 30, 39)
# 31bsưvạnhạnh,phường3quận10,tp,,
# ('quận10', 20, 26)
# 31bsưvạnhạnh,phường3,,tp,,
# ('phường3', 13, 20)
# 31bsưvạnhạnh,,,,tp,,
# tềlễtamnông,phúthọ
# ('phúthọ', 12, 18)
# tềlễtamnông,,
# ('tamnông', 4, 11)
# tềlễ,,,
# ('tềlễ', 0, 4)
# ,,,,
# số10,ngách43/3,ngõ43nguyễnngọcnại,khươngmai,thanhxuân,hànội
# ('hànội', 54, 59)
# số10,ngách43/3,ngõ43nguyễnngọcnại,khươngmai,thanhxuân,,
# ('thanhxuân', 44, 53)
# số10,ngách43/3,ngõ43nguyễnngọcnại,khươngmai,,,,
# ('khươngmai', 34, 43)
# số10,ngách43/3,ngõ43nguyễnngọcnại,,,,,,
# 191anguyễnthịđịnhanphú,quận2,tphồchíminh
# ('hồchíminh', 31, 40)
# 191anguyễnthịđịnhanphú,quận2,tp,
# ('quận2', 23, 28)
# 191anguyễnthịđịnhanphú,,,tp,
# ('anphú', 17, 22)
# 191anguyễnthịđịnh,,,,tp,
# tườngngãinhơnbình,tràôn,vĩnhlong
# ('vĩnhlong', 24, 32)
# tườngngãinhơnbình,tràôn,,
# ('tràôn', 18, 23)
# tườngngãinhơnbình,,,,
# ('nhơnbình', 9, 17)
# tườngngãi,,,,,
# tổ03hòathọđông,cẩmlệ,đànẵng
# ('đànẵng', 21, 27)
# tổ03hòathọđông,cẩmlệ,,
# ('cẩmlệ', 15, 20)
# tổ03hòathọđông,,,,
# ('hòathọđông', 4, 14)
# tổ03,,,,,
# khu5,ngôquyền,vĩnhyênvĩnhphúc
# ('vĩnhphúc', 21, 29)
# khu5,ngôquyền,vĩnhyên,
# ('vĩnhyên', 14, 21)
# khu5,ngôquyền,,,
# ('ngôquyền', 5, 13)
# khu5,,,,,
# tổ11,ấptâykimsơn,châuthành,tiềngiang
# ('tiềngiang', 27, 36)
# tổ11,ấptâykimsơn,châuthành,,
# ('châuthành', 17, 26)
# tổ11,ấptâykimsơn,,,,
# ('kimsơn', 10, 16)
# tổ11,ấptây,,,,,
# số1410đường30/4,phường12,thànhphốvũngtàu,bàrịa-vũngtàu
# ('bàrịa-vũngtàu', 41, 54)
# số1410đường30/4,phường12,thànhphốvũngtàu,,
# ('vũngtàu', 33, 40)
# số1410đường30/4,phường12,thànhphố,,,
# ('phường12', 16, 24)
# số1410đường30/4,,,thànhphố,,,
# f2bphanvăntrp5,gv,tphồchíminh
# ('hồchíminh', 20, 29)
# f2bphanvăntrp5,gv,tp,
# f2bphanvăntrp5,gv,tp,
# ('p5', 12, 14)
# f2bphanvăntr,,gv,tp,
# chiêuyênyênsơn,tuyênquang
# ('tuyênquang', 15, 25)
# chiêuyênyênsơn,,
# ('yênsơn', 8, 14)
# chiêuyên,,,
# ('chiêuyên', 0, 8)
# ,,,,
# ấpthạnhhiệphòathạnh,tambình,vĩnhlong
# ('vĩnhlong', 28, 36)
# ấpthạnhhiệphòathạnh,tambình,,
# ('tambình', 20, 27)
# ấpthạnhhiệphòathạnh,,,,
# ('hòathạnh', 11, 19)
# ấpthạnhhiệp,,,,,
# phườnglêhồngphongtp,quynhơn,bìnhđịnh
# ('bìnhđịnh', 28, 36)
# phườnglêhồngphongtp,quynhơn,,
# ('quynhơn', 20, 27)
# phườnglêhồngphongtp,,,,
# ('lêhồngphong', 6, 17)
# phường,tp,,,,
# 7/3/4/16thànhtháiphường14,quận10,tp,hồchíminh
# ('hồchíminh', 36, 45)
# 7/3/4/16thànhtháiphường14,quận10,tp,,
# ('quận10', 26, 32)
# 7/3/4/16thànhtháiphường14,,,tp,,
# ('phường14', 17, 25)
# 7/3/4/16thànhthái,,,,tp,,
# ấpbùngbinh,hưngthuận,trảngbàng,tâyninh
# ('tâyninh', 31, 38)
# ấpbùngbinh,hưngthuận,trảngbàng,,
# ('trảngbàng', 21, 30)
# ấpbùngbinh,hưngthuận,,,,
# ('hưngthuận', 11, 20)
# ấpbùngbinh,,,,,,
# quangxá,quanghưng,phùcừ,hưngyên
# ('hưngyên', 24, 31)
# quangxá,quanghưng,phùcừ,,
# ('phùcừ', 18, 23)
# quangxá,quanghưng,,,,
# ('quanghưng', 8, 17)
# quangxá,,,,,,
# thônlùngbẻkimlinh,vịxuyên,hàgiang
# ('hàgiang', 26, 33)
# thônlùngbẻkimlinh,vịxuyên,,
# ('vịxuyên', 18, 25)
# thônlùngbẻkimlinh,,,,
# ('kimlinh', 10, 17)
# thônlùngbẻ,,,,,
# krôngbúk,krôngpăc,đắklắk
# ('đắklắk', 18, 24)
# krôngbúk,krôngpăc,,
# krôngbúk,krôngpăc,,
# ('krôngbúk', 0, 8)
# ,,krôngpăc,,
# 820/12hậugiang,phường12quận6,tp,hồchíminh
# ('hồchíminh', 32, 41)
# 820/12hậugiang,phường12quận6,tp,,
# ('quận6', 23, 28)
# 820/12hậugiang,phường12,,tp,,
# ('phường12', 15, 23)
# 820/12hậugiang,,,,tp,,
# mỹhưnghòa,mỹxương,caolãnh,đồngtháp
# ('đồngtháp', 26, 34)
# mỹhưnghòa,mỹxương,caolãnh,,
# ('caolãnh', 18, 25)
# mỹhưnghòa,mỹxương,,,,
# ('mỹxương', 10, 17)
# mỹhưnghòa,,,,,,
# liênminh,tháinguyên
# ('tháinguyên', 9, 19)
# liênminh,,
# liênminh,,
# ('liênminh', 0, 8)
# ,,,
# xbìnhthuậnhtâyson,bìnhđịnh
# ('bìnhđịnh', 18, 26)
# xbìnhthuậnhtâyson,,
# xbìnhthuậnhtâyson,,
# ('bìnhthuận', 1, 10)
# x,htâyson,,
# giaviễn,t,ninhbinh
# ('ninhbinh', 10, 18)
# giaviễn,t,,
# ('giaviễn', 0, 7)
# ,,t,,
# ,,t,,
# chợchu,tháinguyên
# ('tháinguyên', 7, 17)
# chợchu,,
# chợchu,,
# ('chợchu', 0, 6)
# ,,,
# hảiba,hảilăng
# hảiba,hảilăng
# ('hảilăng', 6, 13)
# hảiba,,
# ('hảiba', 0, 5)
# ,,,
# cẩmthủy,thanhhóa
# ('thanhhóa', 8, 16)
# cẩmthủy,,
# ('cẩmthủy', 0, 7)
# ,,,
# ,,,
# phườngphúlợi,tbìnhdương
# ('bìnhdương', 14, 23)
# phườngphúlợi,t,
# phườngphúlợi,t,
# ('phúlợi', 6, 12)
# phường,,t,
# tựlạn,việtyên,bắcgiang
# ('bắcgiang', 14, 22)
# tựlạn,việtyên,,
# ('việtyên', 6, 13)
# tựlạn,,,,
# ('tựlạn', 0, 5)
# ,,,,,
# bìnhhiệp,hbìnhsơn,quảngngãi
# ('quảngngãi', 18, 27)
# bìnhhiệp,hbìnhsơn,,
# ('bìnhsơn', 10, 17)
# bìnhhiệp,h,,,
# ('bìnhhiệp', 0, 8)
# ,,h,,,
# x,tràsơn,tràbồng,tquảngmngãi
# x,tràsơn,tràbồng,tquảngmngãi
# ('tràbồng', 9, 16)
# x,tràsơn,,,tquảngmngãi
# ('tràsơn', 2, 8)
# x,,,,,tquảngmngãi
# xvĩnhlợi,châuthành,angiang
# ('angiang', 19, 26)
# xvĩnhlợi,châuthành,,
# ('châuthành', 9, 18)
# xvĩnhlợi,,,,
# ('vĩnhlợi', 1, 8)
# x,,,,,
# vanđiểm,hhườngtlín,thànhphốhanội
# vanđiểm,hhườngtlín,thànhphốhanội
# vanđiểm,hhườngtlín,thànhphốhanội
# vanđiểm,hhườngtlín,thànhphốhanội
# yênbình,yênbình,yênbái
# ('yênbái', 16, 22)
# yênbình,yênbình,,
# ('yênbình', 8, 15)
# yênbình,,,,
# ('yênbình', 0, 7)
# ,,,,,
# xthạnhđức,hgòdầ6u,tâyninh
# ('tâyninh', 18, 25)
# xthạnhđức,hgòdầ6u,,
# xthạnhđức,hgòdầ6u,,
# ('thạnhđức', 1, 9)
# x,,hgòdầ6u,,
# xthàiphìntủng,đồggvan,hàgxiang
# xthàiphìntủng,đồggvan,hàgxiang
# xthàiphìntủng,đồggvan,hàgxiang
# ('thàiphìntủng', 1, 13)
# x,,đồggvan,hàgxiang
# bùgiamập,tbìnhphước
# ('bìnhphước', 10, 19)
# bùgiamập,t,
# ('bùgiamập', 0, 8)
# ,,t,
# ,,t,
# mỹlươngyênlập
# mỹlươngyênlập
# ('yênlập', 7, 13)
# mỹlương,
# ('mỹlương', 0, 7)
# ,,
# hnqmđàn,nghệan
# ('nghệan', 8, 14)
# hnqmđàn,,
# hnqmđàn,,
# hnqmđàn,,
# hnamtrực,namđị8nh
# hnamtrực,namđị8nh
# ('namtrực', 1, 8)
# h,,namđị8nh
# h,,namđị8nh
# tamgiangnămcăntcàmau
# ('càmau', 15, 20)
# tamgiangnămcănt,
# ('nămcăn', 8, 14)
# tamgiang,t,
# ('tamgiang', 0, 8)
# ,,t,
# khánhsơntkhánhhòa
# ('khánhhòa', 9, 17)
# khánhsơnt,
# ('khánhsơn', 0, 8)
# ,t,
# ,t,
# ladêê,quảngnam
# ('quảngnam', 6, 14)
# ladêê,,
# ladêê,,
# ('ladêê', 0, 5)
# ,,,
# xtânthạnh,hanminh
# xtânthạnh,hanminh
# ('anminh', 11, 17)
# xtânthạnh,h,
# ('tânthạnh', 1, 9)
# x,,h,
# xcambình,thànhfhốcamrah,khánhhòa
# ('khánhhòa', 24, 32)
# xcambình,thànhfhốcamrah,,
# xcambình,thànhfhốcamrah,,
# ('cambình', 1, 8)
# x,,thànhfhốcamrah,,
# xuthạnhlợi,longan
# ('longan', 11, 17)
# xuthạnhlợi,,
# xuthạnhlợi,,
# ('thạnhlợi', 2, 10)
# xu,,,
# minhtân,hlưngtai
# minhtân,hlưngtai
# minhtân,hlưngtai
# ('minhtân', 0, 7)
# ,,hlưngtai
# quỳn1lâm,h,quỳnhphụ,thaibình
# quỳn1lâm,h,quỳnhphụ,thaibình
# ('quỳnhphụ', 11, 19)
# quỳn1lâm,h,,,thaibình
# quỳn1lâm,h,,,thaibình
# xnàtấu,tđiệnbiên
# ('điệnbiên', 8, 16)
# xnàtấu,t,
# xnàtấu,t,
# ('nàtấu', 1, 6)
# x,,t,
# xhieptung,nămcăn,càmau
# ('càmau', 17, 22)
# xhieptung,nămcăn,,
# ('nămcăn', 10, 16)
# xhieptung,,,,
# ('hieptung', 1, 9)
# x,,,,,
# yênbình,hfhữulũng,lạngsơn
# ('lạngsơn', 18, 25)
# yênbình,hfhữulũng,,
# ('hữulũng', 10, 17)
# yênbình,hf,,,
# ('yênbình', 0, 7)
# ,,hf,,,
# ptựanm,phốbuônmathuột,t,đắklăk
# ptựanm,phốbuônmathuột,t,đắklăk
# ('buônmathuột', 10, 21)
# ptựanm,phố,,t,đắklăk
# ('tựan', 1, 5)
# p,m,phố,,t,đắklăk
# xđứcbác,sônglô,tvĩnhphúc
# ('vĩnhphúc', 16, 24)
# xđứcbác,sônglô,t,
# ('sônglô', 8, 14)
# xđứcbác,,,t,
# ('đứcbác', 1, 7)
# x,,,,t,
# châuthành,tiềngiang
# ('tiềngiang', 10, 19)
# châuthành,,
# ('châuthành', 0, 9)
# ,,,
# ,,,
# h,địnhquán,đồngnai
# ('đồngnai', 11, 18)
# h,địnhquán,,
# ('địnhquán', 2, 10)
# h,,,,
# h,,,,
# tpphổyên,tháinguyên
# ('tháinguyên', 9, 19)
# tpphổyên,,
# ('phổyên', 2, 8)
# tp,,,
# tp,,,
# x,hàhồih,thườngtintphànội
# ('hànội', 20, 25)
# x,hàhồih,thườngtintp,
# x,hàhồih,thườngtintp,
# ('hàhồi', 2, 7)
# x,,h,thườngtintp,
# hiêphòabắcgiang
# ('bắcgiang', 7, 15)
# hiêphòa,
# hiêphòa,
# hiêphòa,
# đônggiang,quảygnm
# đônggiang,quảygnm
# ('đônggiang', 0, 9)
# ,,quảygnm
# ,,quảygnm
# sơnthủy,quảngbình
# ('quảngbình', 8, 17)
# sơnthủy,,
# sơnthủy,,
# ('sơnthủy', 0, 7)
# ,,,
# x,hoằnglưu,hoănghóa,thanhhóa
# ('thanhhóa', 20, 28)
# x,hoằnglưu,hoănghóa,,
# x,hoằnglưu,hoănghóa,,
# ('hoằnglưu', 2, 10)
# x,,,hoănghóa,,
# xantiến,h,anlão
# xantiến,h,anlão
# ('anlão', 10, 15)
# xantiến,h,,
# ('antiến', 1, 7)
# x,,h,,
# xgiahội,hvănchấn,yênkbái
# xgiahội,hvănchấn,yênkbái
# ('vănchấn', 9, 16)
# xgiahội,h,,yênkbái
# ('giahội', 1, 7)
# x,,h,,yênkbái
# tamvăn,xlangchánh,thanhhóa
# ('thanhhóa', 18, 26)
# tamvăn,xlangchánh,,
# ('langchánh', 8, 17)
# tamvăn,x,,,
# ('tamvăn', 0, 6)
# ,,x,,,
# x,hodngquỳ,9hanhhóa
# x,hodngquỳ,9hanhhóa
# x,hodngquỳ,9hanhhóa
# x,hodngquỳ,9hanhhóa
# bìnhchau,bìnhsơn,quảngngãi
# ('quảngngãi', 17, 26)
# bìnhchau,bìnhsơn,,
# ('bìnhsơn', 9, 16)
# bìnhchau,,,,
# bìnhchau,,,,
# xtântiến,hđồngphú
# xtântiến,hđồngphú
# ('đồngphú', 10, 17)
# xtântiến,h,
# ('tântiến', 1, 8)
# x,,h,
# fhimlam,điệnbiê
# fhimlam,điệnbiê
# fhimlam,điệnbiê
# ('himlam', 1, 7)
# f,,điệnbiê
# phòaquýqngũhànhsơnđànẵng
# ('đànẵng', 18, 24)
# phòaquýqngũhànhsơn,
# ('ngũhànhsơn', 8, 18)
# phòaquýq,,
# ('hòaquý', 1, 7)
# p,q,,
# bảinsenhmườngkhươngt5làocai
# ('làocai', 21, 27)
# bảinsenhmườngkhươngt5,
# ('mườngkhương', 8, 19)
# bảinsenh,t5,
# bảinsenh,t5,
# xphongquang,hkuyệnvịxuyên,hàgiang
# ('hàgiang', 26, 33)
# xphongquang,hkuyệnvịxuyên,,
# ('vịxuyên', 18, 25)
# xphongquang,hkuyện,,,
# ('phongquang', 1, 11)
# x,,hkuyện,,,
# vninh,kiênxương
# vninh,kiênxương
# vninh,kiênxương
# vninh,kiênxương
# tpbiênhòa,đyngnai
# tpbiênhòa,đyngnai
# ('biênhòa', 2, 9)
# tp,,đyngnai
# tp,,đyngnai
# x,tràdvưongbắctràmytquảgnam
# x,tràdvưongbắctràmytquảgnam
# ('bắctràmy', 11, 19)
# x,tràdvưong,tquảgnam
# x,tràdvưong,tquảgnam
# xvĩnhthắnggòquao,kiêngiang
# ('kiêngiang', 17, 26)
# xvĩnhthắnggòquao,,
# ('gòquao', 10, 16)
# xvĩnhthắng,,,
# ('vĩnhthắng', 1, 10)
# x,,,,
# hbắcmê,hàgiang
# ('hàgiang', 7, 14)
# hbắcmê,,
# ('bắcmê', 1, 6)
# h,,,
# h,,,
# xthiếtkế,hbáthước
# xthiếtkế,hbáthước
# ('báthước', 10, 17)
# xthiếtkế,h,
# ('thiếtkế', 1, 8)
# x,,h,
# phưngkhâmthiênquậnđđa,phốhànội
# ('hànội', 25, 30)
# phưngkhâmthiênquậnđđa,phố,
# phưngkhâmthiênquậnđđa,phố,
# ('khâmthiên', 5, 14)
# phưng,quậnđđa,phố,
# xquỳnhnuyên,t,tháibình
# ('tháibình', 14, 22)
# xquỳnhnuyên,t,,
# xquỳnhnuyên,t,,
# xquỳnhnuyên,t,,
# xvnhhung,tthanhhóa
# ('thanhhóa', 10, 18)
# xvnhhung,t,
# xvnhhung,t,
# xvnhhung,t,
# xtăngthanh,hyênthành
# xtăngthanh,hyênthành
# ('yênthành', 12, 20)
# xtăngthanh,h,
# xtăngthanh,h,
# trunglập,vĩnhbảo,7
# trunglập,vĩnhbảo,7
# ('vĩnhbảo', 9, 16)
# trunglập,,,7
# ('trunglập', 0, 8)
# ,,,,7
# phườngngocthụy,thànhphốhànội
# ('hànội', 23, 28)
# phườngngocthụy,thànhphố,
# phườngngocthụy,thànhphố,
# phườngngocthụy,thànhphố,
# maỹlộc,dnamđịnh
# ('namđịnh', 8, 15)
# maỹlộc,d,
# maỹlộc,d,
# maỹlộc,d,
# xyênlạc,nhuthanh,thanhhóa
# ('thanhhóa', 17, 25)
# xyênlạc,nhuthanh,,
# ('nhuthanh', 8, 16)
# xyênlạc,,,,
# ('yênlạc', 1, 7)
# x,,,,,
# ttqu7nhất,namđịnh
# ('namđịnh', 10, 17)
# ttqu7nhất,,
# ttqu7nhất,,
# ttqu7nhất,,
# qxtânhưngtây,ph8tân
# qxtânhưngtây,ph8tân
# ('tânhưng', 2, 9)
# qx,tây,ph8tân
# qx,tây,ph8tân
# cẩmthủy,tthanhhóca
# cẩmthủy,tthanhhóca
# ('cẩmthủy', 0, 7)
# ,,tthanhhóca
# ,,tthanhhóca
# xphongdụ,quảngninh
# ('quảngninh', 9, 18)
# xphongdụ,,
# xphongdụ,,
# ('phongdụ', 1, 8)
# x,,,
# phúhưng,tbếntre
# ('bếntre', 9, 15)
# phúhưng,t,
# phúhưng,t,
# ('phúhưng', 0, 7)
# ,,t,
# xanthủy,lệethủytquảngbình
# ('quảngbình', 16, 25)
# xanthủy,lệethủyt,
# xanthủy,lệethủyt,
# ('anthủy', 1, 7)
# x,,lệethủyt,
# xbìnhphún,cànglong,tutràvinh
# ('tràvinh', 21, 28)
# xbìnhphún,cànglong,tu,
# ('cànglong', 10, 18)
# xbìnhphún,,,tu,
# ('bìnhphú', 1, 8)
# x,n,,,tu,
# phưongthọson,phốviệttrì,phúthọ
# ('phúthọ', 24, 30)
# phưongthọson,phốviệttrì,,
# ('việttrì', 16, 23)
# phưongthọson,phố,,,
# phưongthọson,phố,,,
# xhòabqc,hdilinh
# xhòabqc,hdilinh
# ('dilinh', 9, 15)
# xhòabqc,h,
# xhòabqc,h,
# cộnghòa,haoidương
# cộnghòa,haoidương
# cộnghòa,haoidương
# ('cộnghòa', 0, 7)
# ,,haoidương
# đaitan,đạiộc,quảngnam
# ('quảngnam', 13, 21)
# đaitan,đạiộc,,
# đaitan,đạiộc,,
# đaitan,đạiộc,,
# hbảolâm8caobằng
# ('caobằng', 8, 15)
# hbảolâm8,
# ('bảolâm', 1, 7)
# h,8,
# h,8,
# x,sinsuốihồhphongthổ,laichâu
# ('laichâu', 21, 28)
# x,sinsuốihồhphongthổ,,
# ('phongthổ', 12, 20)
# x,sinsuốihồh,,,
# ('sinsuốihồ', 2, 11)
# x,,h,,,
# xsùngphài,pzaichâu,laichâu
# ('laichâu', 19, 26)
# xsùngphài,pzaichâu,,
# xsùngphài,pzaichâu,,
# ('sùngphài', 1, 9)
# x,,pzaichâu,,
# anlowngphúgiáotbinhdương
# anlowngphúgiáotbinhdương
# ('phúgiáo', 7, 14)
# anlowng,tbinhdương
# anlowng,tbinhdương
# xtân7thịnh,yiênbái,yênbái
# ('yênbái', 19, 25)
# xtân7thịnh,yiênbái,,
# xtân7thịnh,yiênbái,,
# xtân7thịnh,yiênbái,,
# xkhoansơn,tiêndu,bacninh
# ('bacninh', 17, 24)
# xkhoansơn,tiêndu,,
# ('tiêndu', 10, 16)
# xkhoansơn,,,,
# xkhoansơn,,,,
# hảian,hảilăngtqdungtrị
# hảian,hảilăngtqdungtrị
# ('hảilăng', 6, 13)
# hảian,,tqdungtrị
# ('hảian', 0, 5)
# ,,,tqdungtrị
# tphàtiên,kiêngiang
# ('kiêngiang', 9, 18)
# tphàtiên,,
# ('hàtiên', 2, 8)
# tp,,,
# tp,,,
# hairiênghsônghinh
# hairiênghsônghinh
# ('sônghinh', 9, 17)
# hairiêngh,
# ('hairiêng', 0, 8)
# ,h,
# x,diễnthành,diênchâu
# x,diễnthành,diênchâu
# x,diễnthành,diênchâu
# ('diễnthành', 2, 11)
# x,,,diênchâu
# bảolâ,caobằng
# ('caobằng', 6, 13)
# bảolâ,,
# bảolâ,,
# bảolâ,,
# thanhvĩnhđông,châuthành,tlongan
# ('longan', 25, 31)
# thanhvĩnhđông,châuthành,t,
# ('châuthành', 14, 23)
# thanhvĩnhđông,,,t,
# ('thanhvĩnhđông', 0, 13)
# ,,,,t,
# xchêla,thàgianz
# xchêla,thàgianz
# xchêla,thàgianz
# xchêla,thàgianz
# hônosỹ,caobằng
# ('caobằng', 7, 14)
# hônosỹ,,
# hônosỹ,,
# hônosỹ,,
# x,hànhtíntây,quảngngãi
# ('quảngngãi', 13, 22)
# x,hànhtíntây,,
# x,hànhtíntây,,
# ('hànhtíntây', 2, 12)
# x,,,,
# fanlacchílinh,hảidương
# ('hảidương', 14, 22)
# fanlacchílinh,,
# ('chílinh', 6, 13)
# fanlac,,,
# ('anlac', 1, 6)
# f,,,,
# hxuânlộc,đồngnai
# ('đồngnai', 9, 16)
# hxuânlộc,,
# ('xuânlộc', 1, 8)
# h,,,
# h,,,
# hòalợi,tràvinh
# ('tràvinh', 7, 14)
# hòalợi,,
# hòalợi,,
# ('hòalợi', 0, 6)
# ,,,
# phườnghiệan,txkinhmôn,hảidương
# ('hảidương', 22, 30)
# phườnghiệan,txkinhmôn,,
# ('kinhmôn', 14, 21)
# phườnghiệan,tx,,,
# phườnghiệan,tx,,,
# trịnhtườnghbátxát
# trịnhtườnghbátxát
# ('bátxát', 11, 17)
# trịnhtườngh,
# ('trịnhtường', 0, 10)
# ,h,
# chiềngmu5ng,stnla
# chiềngmu5ng,stnla
# chiềngmu5ng,stnla
# chiềngmu5ng,stnla
# fmễtrì,namtừliêm,thànhphốhn
# fmễtrì,namtừliêm,thànhphốhn
# ('namtừliêm', 7, 16)
# fmễtrì,,,thànhphốhn
# ('mễtrì', 1, 6)
# f,,,,thànhphốhn
# p4,ph9ốđônghà
# p4,ph9ốđônghà
# ('đônghà', 7, 13)
# p4,ph9ố,
# ('p4', 0, 2)
# ,,ph9ố,
# f,trầnhưngđao,phủly,h,nam
# f,trầnhưngđao,phủly,h,nam
# f,trầnhưngđao,phủly,h,nam
# f,trầnhưngđao,phủly,h,nam
# tônglạnhhthuậnchrutsơnla
# ('sơnla', 19, 24)
# tônglạnhhthuậnchrut,
# tônglạnhhthuậnchrut,
# ('tônglạnh', 0, 8)
# ,hthuậnchrut,
# tphôsôngcông,tháinguyên
# ('tháinguyên', 13, 23)
# tphôsôngcông,,
# ('sôngcông', 4, 12)
# tphô,,,
# tphô,,,
# f07,q6
# f07,q6
# ('q6', 4, 6)
# f07,,
# f07,,
# pxuânlam,thuậnthành,tbắcninh
# ('bắcninh', 21, 28)
# pxuânlam,thuậnthành,t,
# ('thuậnthành', 9, 19)
# pxuânlam,,,t,
# pxuânlam,,,t,
# đônghkbangtgialai
# ('gialai', 11, 17)
# đônghkbangt,
# ('kbang', 5, 10)
# đôngh,t,
# ('đông', 0, 4)
# ,h,t,
# longthắng,huynlaiung
# longthắng,huynlaiung
# longthắng,huynlaiung
# ('longthắng', 0, 9)
# ,,huynlaiung
# lưusơn,h,đôlương,nghệan
# ('nghệan', 17, 23)
# lưusơn,h,đôlương,,
# ('đôlương', 9, 16)
# lưusơn,h,,,,
# ('lưusơn', 0, 6)
# ,,h,,,,
# chilăng,hchilăng,lạng5sơn
# chilăng,hchilăng,lạng5sơn
# ('chilăng', 9, 16)
# chilăng,h,,lạng5sơn
# ('chilăng', 0, 7)
# ,,h,,lạng5sơn
# bằnglng,tbắckạn
# ('bắckạn', 9, 15)
# bằnglng,t,
# bằnglng,t,
# bằnglng,t,
# tânbiên,tdyninh
# tânbiên,tdyninh
# ('tânbiên', 0, 7)
# ,,tdyninh
# ,,tdyninh
# thanhmiện,hảidương
# ('hảidương', 10, 18)
# thanhmiện,,
# ('thanhmiện', 0, 9)
# ,,,
# ,,,
# x,tânan,thnhhà
# x,tânan,thnhhà
# x,tânan,thnhhà
# ('tânan', 2, 7)
# x,,,thnhhà
# trbungthanh,tthanhhóa
# ('thanhhóa', 13, 21)
# trbungthanh,t,
# trbungthanh,t,
# trbungthanh,t,
# vĩnhhưng,longan
# ('longan', 9, 15)
# vĩnhhưng,,
# vĩnhhưng,,
# ('vĩnhhưng', 0, 8)
# ,,,
# phường04,thànhphốhồchiminh
# phường04,thànhphốhồchiminh
# phường04,thànhphốhồchiminh
# ('phường04', 0, 8)
# ,,thànhphốhồchiminh
# nâmntừ,nậmpồ
# nâmntừ,nậmpồ
# ('nậmpồ', 7, 12)
# nâmntừ,,
# nâmntừ,,
# xchâuthuận7,tnghệan
# ('nghệan', 13, 19)
# xchâuthuận7,t,
# xchâuthuận7,t,
# ('châuthuận', 1, 10)
# x,7,t,
# pvănđẩu,qkiếnan,thànhmphốhảiphòng
# ('hảiphòng', 25, 33)
# pvănđẩu,qkiếnan,thànhmphố,
# ('kiếnan', 9, 15)
# pvănđẩu,q,,thànhmphố,
# ('vănđẩu', 1, 7)
# p,,q,,thànhmphố,
# cẩmlươnghcẩmthủa,thanhhóa
# ('thanhhóa', 17, 25)
# cẩmlươnghcẩmthủa,,
# cẩmlươnghcẩmthủa,,
# ('cẩmlương', 0, 8)
# ,hcẩmthủa,,
# hphúbình,tháinguyên
# ('tháinguyên', 9, 19)
# hphúbình,,
# ('phúbình', 1, 8)
# h,,,
# h,,,
# phườnghòaihảo,t,hoainhơn,tbìnhđinh
# phườnghòaihảo,t,hoainhơn,tbìnhđinh
# phườnghòaihảo,t,hoainhơn,tbìnhđinh
# ('hòaihảo', 6, 13)
# phường,,t,hoainhơn,tbìnhđinh
# hướnghiệp,đakrông,quảngtrz
# hướnghiệp,đakrông,quảngtrz
# ('đakrông', 10, 17)
# hướnghiệp,,,quảngtrz
# ('hướnghiệp', 0, 9)
# ,,,,quảngtrz
# peatam,pbuônmathuộttỉnđắkllk
# peatam,pbuônmathuộttỉnđắkllk
# ('buônmathuột', 8, 19)
# peatam,p,tỉnđắkllk
# ('eatam', 1, 6)
# p,,p,tỉnđắkllk
# tânan,h,vĩnhcửu,đồngnai
# ('đồngnai', 16, 23)
# tânan,h,vĩnhcửu,,
# ('vĩnhcửu', 8, 15)
# tânan,h,,,,
# ('tânan', 0, 5)
# ,,h,,,,
# ftândân,t,nghisơn,thanhhóa
# ('thanhhóa', 18, 26)
# ftândân,t,nghisơn,,
# ('nghisơn', 10, 17)
# ftândân,t,,,,
# ('tândân', 1, 7)
# f,,t,,,,
# xnamcát,namđàn
# xnamcát,namđàn
# ('namđàn', 8, 14)
# xnamcát,,
# ('namcát', 1, 7)
# x,,,
# vịtân,vịthan
# vịtân,vịthan
# vịtân,vịthan
# ('vịtân', 0, 5)
# ,,vịthan
# xmythànhbac,cailậy
# xmythànhbac,cailậy
# ('cailậy', 12, 18)
# xmythànhbac,,
# xmythànhbac,,
# xcưdrămbhkrôngbông
# xcưdrămbhkrôngbông
# ('krôngbông', 9, 18)
# xcưdrămbh,
# ('cưdrăm', 1, 7)
# x,bh,
# xbìnhhi,tquảcgnam
# xbìnhhi,tquảcgnam
# xbìnhhi,tquảcgnam
# xbìnhhi,tquảcgnam
# nânchính,hlynhân,hanam
# ('hanam', 17, 22)
# nânchính,hlynhân,,
# nânchính,hlynhân,,
# nânchính,hlynhân,,
# khảcửu,h,thanhsrn
# khảcửu,h,thanhsrn
# khảcửu,h,thanhsrn
# ('khảcửu', 0, 6)
# ,,h,thanhsrn
# đônghòa,phúyn
# đônghòa,phúyn
# ('đônghòa', 0, 7)
# ,,phúyn
# ,,phúyn
# đắktô,kontum
# ('kontum', 6, 12)
# đắktô,,
# ('đắktô', 0, 5)
# ,,,
# ,,,
# nôngtrườngviệtlâm,vịxuyen,hagiang
# ('hagiang', 26, 33)
# nôngtrườngviệtlâm,vịxuyen,,
# nôngtrườngviệtlâm,vịxuyen,,
# ('nôngtrườngviệtlâm', 0, 17)
# ,,vịxuyen,,
# q11,hồchíminh
# ('hồchíminh', 4, 13)
# q11,,
# ('q11', 0, 3)
# ,,,
# ,,,
# h,đăkđoa,gialai
# ('gialai', 9, 15)
# h,đăkđoa,,
# ('đăkđoa', 2, 8)
# h,,,,
# h,,,,
# flowngbinh,tpthủđưc,tphcm
# ('hcm', 22, 25)
# flowngbinh,tpthủđưc,tp,
# flowngbinh,tpthủđưc,tp,
# flowngbinh,tpthủđưc,tp,
# đôngcường,hđônghưng
# đôngcường,hđônghưng
# ('đônghưng', 11, 19)
# đôngcường,h,
# ('đôngcường', 0, 9)
# ,,h,
# xtrungnghĩa,thưngyên
# ('hưngyên', 13, 20)
# xtrungnghĩa,t,
# xtrungnghĩa,t,
# ('trungnghĩa', 1, 11)
# x,,t,
# chưse,gialai
# ('gialai', 6, 12)
# chưse,,
# chưse,,
# chưse,,
# x,hảiminh,n5amđịnh
# x,hảiminh,n5amđịnh
# x,hảiminh,n5amđịnh
# ('hảiminh', 2, 9)
# x,,,n5amđịnh
# đạilộc,quảngnam
# ('quảngnam', 7, 15)
# đạilộc,,
# ('đạilộc', 0, 6)
# ,,,
# ,,,
# bạchlưu,hsonglô,vĩnhpghúc
# bạchlưu,hsonglô,vĩnhpghúc
# bạchlưu,hsonglô,vĩnhpghúc
# ('bạchlưu', 0, 7)
# ,,hsonglô,vĩnhpghúc
# xđềthám,lạngsơn
# ('lạngsơn', 8, 15)
# xđềthám,,
# xđềthám,,
# ('đềthám', 1, 7)
# x,,,
# phườnghàmãn,txthuậnthành
# phườnghàmãn,txthuậnthành
# ('thuậnthành', 14, 24)
# phườnghàmãn,tx,
# ('hàmãn', 6, 11)
# phường,,tx,
# xasơnthyh,lethủy,quảngbình
# ('quảngbình', 17, 26)
# xasơnthyh,lethủy,,
# xasơnthyh,lethủy,,
# xasơnthyh,lethủy,,
# x,namthaia,azbiên,kiêngiang
# ('kiêngiang', 18, 27)
# x,namthaia,azbiên,,
# x,namthaia,azbiên,,
# ('namthaia', 2, 10)
# x,,,azbiên,,
# p,quảngthọ,tpsầmswn,ty,thanhhóa
# ('thanhhóa', 23, 31)
# p,quảngthọ,tpsầmswn,ty,,
# p,quảngthọ,tpsầmswn,ty,,
# ('quảngthọ', 2, 10)
# p,,,tpsầmswn,ty,,
# đônghtòaphuyên
# đônghtòaphuyên
# đônghtòaphuyên
# ('đông', 0, 4)
# ,htòaphuyên
# tamamnhnzm,núithànhtquảngnam
# ('quảngnam', 20, 28)
# tamamnhnzm,núithànht,
# ('núithành', 11, 19)
# tamamnhnzm,,t,
# tamamnhnzm,,t,
# xvându,phúthọ
# ('phúthọ', 7, 13)
# xvându,,
# xvându,,
# ('vându', 1, 6)
# x,,,
# p,phongcnốcth,ị,quảngyên,quảngninh
# ('quảngninh', 25, 34)
# p,phongcnốcth,ị,quảngyên,,
# ('quảngyên', 16, 24)
# p,phongcnốcth,ị,,,,
# p,phongcnốcth,ị,,,,
# xanthuận,tbếntre
# ('bếntre', 10, 16)
# xanthuận,t,
# xanthuận,t,
# ('anthuận', 1, 8)
# x,,t,
# nghisơ6n,tx,nghisơn,thhanhhóa
# nghisơ6n,tx,nghisơn,thhanhhóa
# ('nghisơn', 12, 19)
# nghisơ6n,tx,,,thhanhhóa
# nghisơ6n,tx,,,thhanhhóa
# thăngfbìh,t,quảngnam
# ('quảngnam', 12, 20)
# thăngfbìh,t,,
# thăngfbìh,t,,
# thăngfbìh,t,,
# ttđạtẻh,t,lâmđồng
# ('lâmđồng', 10, 17)
# ttđạtẻh,t,,
# ttđạtẻh,t,,
# ('đạtẻh', 2, 7)
# tt,,t,,
# tthộian,tangiang
# ('angiang', 9, 16)
# tthộian,t,
# tthộian,t,
# ('hộian', 2, 7)
# tt,,t,
# x,terườngthịnh,hứnghòa,hànội
# ('hànội', 23, 28)
# x,terườngthịnh,hứnghòa,,
# ('ứnghòa', 16, 22)
# x,terườngthịnh,h,,,
# x,terườngthịnh,h,,,
# xhmỗ,đanphtượng
# xhmỗ,đanphtượng
# xhmỗ,đanphtượng
# xhmỗ,đanphtượng
# tiếnnông,htrệusơn,t,thanhhóa
# ('thanhhóa', 20, 28)
# tiếnnông,htrệusơn,t,,
# tiếnnông,htrệusơn,t,,
# ('tiếnnông', 0, 8)
# ,,htrệusơn,t,,
# bìnhsơn,tquảngngãi
# ('quảngngãi', 9, 18)
# bìnhsơn,t,
# ('bìnhsơn', 0, 7)
# ,,t,
# ,,t,
# quangtiếns6tânyên
# quangtiếns6tânyên
# ('tânyên', 11, 17)
# quangtiếns6,
# ('quangtiến', 0, 9)
# ,s6,
# kẻsặthbinhgiangthảidưong
# kẻsặthbinhgiangthảidưong
# ('binhgiang', 6, 15)
# kẻsặth,thảidưong
# ('kẻsặt', 0, 5)
# ,h,thảidưong
# lươnghòa,benlức
# lươnghòa,benlức
# lươnghòa,benlức
# ('lươnghòa', 0, 8)
# ,,benlức
# xtânson,hchợqmới
# xtânson,hchợqmới
# xtânson,hchợqmới
# xtânson,hchợqmới
# quáchphẩmbắc,càmzu
# quáchphẩmbắc,càmzu
# quáchphẩmbắc,càmzu
# ('quáchphẩmbắc', 0, 12)
# ,,càmzu
# xtvựcđạo,namđịnh
# ('namđịnh', 9, 16)
# xtvựcđạo,,
# xtvựcđạo,,
# xtvựcđạo,,
# tânphong,tthanhhóa
# ('thanhhóa', 10, 18)
# tânphong,t,
# tânphong,t,
# ('tânphong', 0, 8)
# ,,t,
# x,lộcthah,t0pbảolộc,tlâmđông
# x,lộcthah,t0pbảolộc,tlâmđông
# ('bảolộc', 13, 19)
# x,lộcthah,t0p,,tlâmđông
# ('đông', 19, 23)
# x,lộcthah,t0p,,tlâm,
# xđươnghoa,tquảngninh
# ('quảngninh', 11, 20)
# xđươnghoa,t,
# xđươnghoa,t,
# xđươnghoa,t,
# vạnkim,mỹđức,tphnội
# vạnkim,mỹđức,tphnội
# ('mỹđức', 7, 12)
# vạnkim,,,tphnội
# ('vạnkim', 0, 6)
# ,,,,tphnội
# xmiềnđồi,lazcsơn
# xmiềnđồi,lazcsơn
# xmiềnđồi,lazcsơn
# ('miềnđồi', 1, 8)
# x,,lazcsơn
# xphumãn,hn
# xphumãn,hn
# xphumãn,hn
# xphumãn,hn
# h,hồngngự,đồngthap
# h,hồngngự,đồngthap
# ('hồngngự', 2, 9)
# h,,,đồngthap
# h,,,đồngthap
# xmườnglèohsốpcộp,sơnma
# xmườnglèohsốpcộp,sơnma
# ('sốpcộp', 10, 16)
# xmườnglèoh,,sơnma
# ('mườnglèo', 1, 9)
# x,h,,sơnma
# chợgạotỉ,nhtiềngiang
# ('tiềngiang', 11, 20)
# chợgạotỉ,nh,
# ('chợgạo', 0, 6)
# ,tỉ,nh,
# ,tỉ,nh,
# tamxuâni,úithànhquảngnam
# ('quảngnam', 16, 24)
# tamxuâni,úithành,
# tamxuâni,úithành,
# ('tamxuâni', 0, 8)
# ,,úithành,
# mỹđức,hànội
# ('hànội', 6, 11)
# mỹđức,,
# ('mỹđức', 0, 5)
# ,,,
# ,,,
# j,đôlương,nghệan
# ('nghệan', 10, 16)
# j,đôlương,,
# ('đôlương', 2, 9)
# j,,,,
# j,,,,
# xtâmthsắngcưjút,đắknông
# ('đắknông', 16, 23)
# xtâmthsắngcưjút,,
# ('cưjút', 10, 15)
# xtâmthsắng,,,
# xtâmthsắng,,,
# tíchsơn,phốvinhyên,vĩnhphúc
# ('vĩnhphúc', 19, 27)
# tíchsơn,phốvinhyên,,
# tíchsơn,phốvinhyên,,
# ('tíchsơn', 0, 7)
# ,,phốvinhyên,,
# xhòatrịhuzyenhúhoatphúyên
# ('phúyên', 19, 25)
# xhòatrịhuzyenhúhoat,
# xhòatrịhuzyenhúhoat,
# ('hòatrị', 1, 7)
# x,huzyenhúhoat,
# xlasơnh,binhlục
# xlasơnh,binhlục
# xlasơnh,binhlục
# ('lasơn', 1, 6)
# x,h,binhlục
# f,điệnnambắc,xtquảngnam
# ('quảngnam', 15, 23)
# f,điệnnambắc,xt,
# f,điệnnambắc,xt,
# ('điệnnambắc', 2, 12)
# f,,,xt,
# hkrôngnăng,đắklắk
# ('đắklắk', 11, 17)
# hkrôngnăng,,
# ('krôngnăng', 1, 10)
# h,,,
# h,,,
# x,boktớihhòaiân,bìhđịnh
# x,boktớihhòaiân,bìhđịnh
# ('hòaiân', 9, 15)
# x,boktớih,,bìhđịnh
# ('boktới', 2, 8)
# x,,h,,bìhđịnh
# xtânnghia,dilinhlâmđồng
# ('lâmđồng', 16, 23)
# xtânnghia,dilinh,
# ('dilinh', 10, 16)
# xtânnghia,,,
# xtânnghia,,,
# bìnhsa,thăngbình
# bìnhsa,thăngbình
# ('thăngbình', 7, 16)
# bìnhsa,,
# ('bìnhsa', 0, 6)
# ,,,
# hbắcson,lạngson
# hbắcson,lạngson
# hbắcson,lạngson
# hbắcson,lạngson
# xtânlập,hvũthư,tháibình
# ('tháibình', 15, 23)
# xtânlập,hvũthư,,
# ('vũthư', 9, 14)
# xtânlập,h,,,
# ('tânlập', 1, 7)
# x,,h,,,
# tinhnhu,thanhsơn,phútho
# tinhnhu,thanhsơn,phútho
# ('thanhsơn', 8, 16)
# tinhnhu,,,phútho
# tinhnhu,,,phútho
# giavượng,giaviễn
# giavượng,giaviễn
# ('giaviễn', 9, 16)
# giavượng,,
# ('giavượng', 0, 8)
# ,,,
# hợpđức,tphảiphòng
# ('hảiphòng', 9, 17)
# hợpđức,tp,
# hợpđức,tp,
# ('hợpđức', 0, 6)
# ,,tp,
# sôngđốc,tnhcàmau
# ('càmau', 11, 16)
# sôngđốc,tnh,
# sôngđốc,tnh,
# ('sôngđốc', 0, 7)
# ,,tnh,
# htrảngbom,đồngnai
# ('đồngnai', 10, 17)
# htrảngbom,,
# ('trảngbom', 1, 9)
# h,,,
# h,,,
# xvĩnhhanh,châuthành,angiang
# ('angiang', 20, 27)
# xvĩnhhanh,châuthành,,
# ('châuthành', 10, 19)
# xvĩnhhanh,,,,
# ('vĩnhhanh', 1, 9)
# x,,,,,
# xyênphong,bắckạn
# ('bắckạn', 10, 16)
# xyênphong,,
# xyênphong,,
# ('yênphong', 1, 9)
# x,,,
# p,nhithu,cửalòtnghệan
# ('nghệan', 15, 21)
# p,nhithu,cửalòt,
# ('cửalò', 9, 14)
# p,nhithu,,t,
# p,nhithu,,t,
# fdịchvọng,c/giấythànhphốhànội
# ('hànội', 24, 29)
# fdịchvọng,c/giấythànhphố,
# fdịchvọng,c/giấythànhphố,
# ('dịchvọng', 1, 9)
# f,,c/giấythànhphố,
# minhthuận,uminhthượng,kiêngiang
# ('kiêngiang', 22, 31)
# minhthuận,uminhthượng,,
# ('uminhthượng', 10, 21)
# minhthuận,,,,
# ('minhthuận', 0, 9)
# ,,,,,
# eahuar,buônđôn
# eahuar,buônđôn
# ('buônđôn', 7, 14)
# eahuar,,
# ('eahuar', 0, 6)
# ,,,
# xsró,kôngchro,gialai
# ('gialai', 14, 20)
# xsró,kôngchro,,
# ('kôngchro', 5, 13)
# xsró,,,,
# ('sró', 1, 4)
# x,,,,,
# xtânthanh,langgiang
# xtânthanh,langgiang
# ('langgiang', 10, 19)
# xtânthanh,,
# ('tânthanh', 1, 9)
# x,,,
# x,sơnhvhsơnhoa,phúyên
# ('phúyên', 15, 21)
# x,sơnhvhsơnhoa,,
# x,sơnhvhsơnhoa,,
# x,sơnhvhsơnhoa,,
# bảnmyh,hòangsuphì,hàgiang
# ('hàgiang', 18, 25)
# bảnmyh,hòangsuphì,,
# ('hòangsuphì', 7, 17)
# bảnmyh,,,,
# bảnmyh,,,,
# cônghòahkimthành
# cônghòahkimthành
# ('kimthành', 8, 16)
# cônghòah,
# cônghòah,
# chơchun,hnamigiang,tquảngnam
# ('quảngnam', 20, 28)
# chơchun,hnamigiang,t,
# chơchun,hnamigiang,t,
# ('chơchun', 0, 7)
# ,,hnamigiang,t,
# xvôtranh,hlụcnam,bắcgiang
# ('bắcgiang', 17, 25)
# xvôtranh,hlụcnam,,
# ('lụcnam', 10, 16)
# xvôtranh,h,,,
# ('vôtranh', 1, 8)
# x,,h,,,
# bùgiamap,hbùgiamập,bìnhphước
# ('bìnhphước', 19, 28)
# bùgiamap,hbùgiamập,,
# ('bùgiamập', 10, 18)
# bùgiamap,h,,,
# bùgiamap,h,,,
# quỳchâu,nsghệan
# quỳchâu,nsghệan
# ('quỳchâu', 0, 7)
# ,,nsghệan
# ,,nsghệan
# hvăngiang,hưngyê0
# hvăngiang,hưngyê0
# ('văngiang', 1, 9)
# h,,hưngyê0
# h,,hưngyê0
# xbatiêu,batơ,quảngngãi
# ('quảngngãi', 13, 22)
# xbatiêu,batơ,,
# ('batơ', 8, 12)
# xbatiêu,,,,
# ('batiêu', 1, 7)
# x,,,,,
# tânkiênhbìnhchánhthànhphôhôchíminh
# tânkiênhbìnhchánhthànhphôhôchíminh
# ('bìnhchánh', 8, 17)
# tânkiênh,thànhphôhôchíminh
# ('tânkiên', 0, 7)
# ,h,thànhphôhôchíminh
# hthanhliêm,hanam
# ('hanam', 11, 16)
# hthanhliêm,,
# ('thanhliêm', 1, 10)
# h,,,
# h,,,
# chílinh,hảidương
# ('hảidương', 8, 16)
# chílinh,,
# ('chílinh', 0, 7)
# ,,,
# ,,,
# x,tamđồng,mêlinh,tphwhànoi
# x,tamđồng,mêlinh,tphwhànoi
# ('mêlinh', 10, 16)
# x,tamđồng,,,tphwhànoi
# ('tamđồng', 2, 9)
# x,,,,,tphwhànoi
# eăntiến,yênlạc,vĩnhp0húc
# eăntiến,yênlạc,vĩnhp0húc
# ('yênlạc', 8, 14)
# eăntiến,,,vĩnhp0húc
# eăntiến,,,vĩnhp0húc
# f,anphú,x,tịnhbiên,angiang
# ('angiang', 19, 26)
# f,anphú,x,tịnhbiên,,
# ('tịnhbiên', 10, 18)
# f,anphú,x,,,,
# ('anphú', 2, 7)
# f,,,x,,,,
# xcẩmhòang,t,hảidươnwg
# xcẩmhòang,t,hảidươnwg
# xcẩmhòang,t,hảidươnwg
# ('cẩmhòang', 1, 9)
# x,,t,hảidươnwg
# x,catchánh,phùcát
# x,catchánh,phùcát
# ('phùcát', 11, 17)
# x,catchánh,,
# x,catchánh,,
# eakmút,eakar,tỉnwhđắklắk
# ('đắklắk', 18, 24)
# eakmút,eakar,tỉnwh,
# ('eakar', 7, 12)
# eakmút,,,tỉnwh,
# ('eakmút', 0, 6)
# ,,,,tỉnwh,
# 7sơnhà,nhoquantinhninhbình
# ('ninhbình', 18, 26)
# 7sơnhà,nhoquantinh,
# ('nhoquan', 7, 14)
# 7sơnhà,,tinh,
# ('sơnhà', 1, 6)
# 7,,,tinh,
# xmỹthạnh,giongtrôm,bếntre
# ('bếntre', 19, 25)
# xmỹthạnh,giongtrôm,,
# xmỹthạnh,giongtrôm,,
# ('mỹthạnh', 1, 8)
# x,,giongtrôm,,
# châuminh,hhiệpha,tbắcgiang
# ('bắcgiang', 18, 26)
# châuminh,hhiệpha,t,
# châuminh,hhiệpha,t,
# ('châuminh', 0, 8)
# ,,hhiệpha,t,
# xthịnhvượng,a,tgcaobăng
# xthịnhvượng,a,tgcaobăng
# xthịnhvượng,a,tgcaobăng
# ('thịnhvượng', 1, 11)
# x,,a,tgcaobăng
# diênthạnh,tkhabnhhòa
# diênthạnh,tkhabnhhòa
# diênthạnh,tkhabnhhòa
# ('diênthạnh', 0, 9)
# ,,tkhabnhhòa
# xviệthồng,trhàgiang
# ('hàgiang', 12, 19)
# xviệthồng,tr,
# xviệthồng,tr,
# ('việthồng', 1, 9)
# x,,tr,
# xđứcsơnanhsơn
# xđứcsơnanhsơn
# ('anhsơn', 7, 13)
# xđứcsơn,
# ('đứcsơn', 1, 7)
# x,,
# đăknangh,krôngnôtđắknông
# ('đắknông', 17, 24)
# đăknangh,krôngnôt,
# ('krôngnô', 9, 16)
# đăknangh,,t,
# đăknangh,,t,
# xđiệnhồng,điệnbàn,tquảngnam
# ('quảngnam', 19, 27)
# xđiệnhồng,điệnbàn,t,
# ('điệnbàn', 10, 17)
# xđiệnhồng,,,t,
# ('điệnhồng', 1, 9)
# x,,,,t,
# hduyxuyên,tquảngnam
# ('quảngnam', 11, 19)
# hduyxuyên,t,
# ('duyxuyên', 1, 9)
# h,,t,
# h,,t,
# đứlợi,hmộđức,quảnngãi
# đứlợi,hmộđức,quảnngãi
# ('mộđức', 7, 12)
# đứlợi,h,,quảnngãi
# đứlợi,h,,quảnngãi
# phườngnguyễntrãi,tpkontum,kontum
# ('kontum', 26, 32)
# phườngnguyễntrãi,tpkontum,,
# ('kontum', 19, 25)
# phườngnguyễntrãi,tp,,,
# ('nguyễntrãi', 6, 16)
# phường,,tp,,,
# xsonglộchchâuthành
# xsonglộchchâuthành
# ('châuthành', 9, 18)
# xsonglộch,
# ('songlộc', 1, 8)
# x,h,
# lộcchâu,tpbảolộc,tlâmđồng
# ('lâmđồng', 18, 25)
# lộcchâu,tpbảolộc,t,
# ('bảolộc', 10, 16)
# lộcchâu,tp,,t,
# ('lộcchâu', 0, 7)
# ,,tp,,t,
# x,bảnnguyen,lâmthao
# x,bảnnguyen,lâmthao
# ('lâmthao', 12, 19)
# x,bảnnguyen,,
# x,bảnnguyen,,
# phươngcông,huyentiềnhải,ttháibình
# ('tháibình', 25, 33)
# phươngcông,huyentiềnhải,t,
# ('tiềnhải', 16, 23)
# phươngcông,huyen,,t,
# ('phươngcông', 0, 10)
# ,,huyen,,t,
# xlươngnghĩa,h,longmỹ,t,hậugiangg
# ('hậugiang', 23, 31)
# xlươngnghĩa,h,longmỹ,t,,g
# ('longmỹ', 14, 20)
# xlươngnghĩa,h,,,t,,g
# ('lươngnghĩa', 1, 11)
# x,,h,,,t,,g
# xtâyyên,hanbiên,tkiêngiang
# ('kiêngiang', 17, 26)
# xtâyyên,hanbiên,t,
# ('anbiên', 9, 15)
# xtâyyên,h,,t,
# ('tâyyên', 1, 7)
# x,,h,,t,
# kiênthànhhtrấnyên,yênbi
# kiênthànhhtrấnyên,yênbi
# ('trấnyên', 10, 17)
# kiênthànhh,,yênbi
# ('kiênthành', 0, 9)
# ,h,,yênbi
# duyphú,duyxuyen,quangnam
# ('quangnam', 16, 24)
# duyphú,duyxuyen,,
# ('duyxuyen', 7, 15)
# duyphú,,,,
# ('duyphú', 0, 6)
# ,,,,,
# xphướcvĩnhđông,cầngiuộc,longan
# ('longan', 24, 30)
# xphướcvĩnhđông,cầngiuộc,,
# ('cầngiuộc', 15, 23)
# xphướcvĩnhđông,,,,
# ('phướcvĩnhđông', 1, 14)
# x,,,,,
# xthạchxuâ,thạchhà,t,hàtĩnh
# ('hàtĩnh', 20, 26)
# xthạchxuâ,thạchhà,t,,
# ('thạchhà', 10, 17)
# xthạchxuâ,,,t,,
# xthạchxuâ,,,t,,
# quận1,phcminh
# ('hcm', 7, 10)
# quận1,p,inh
# ('quận1', 0, 5)
# ,,p,inh
# ,,p,inh
# sínchéng,simacai,làocai
# ('làocai', 17, 23)
# sínchéng,simacai,,
# ('simacai', 9, 16)
# sínchéng,,,,
# ('sínchéng', 0, 8)
# ,,,,,
# xduyhải,tquảngnam
# ('quảngnam', 9, 17)
# xduyhải,t,
# xduyhải,t,
# ('duyhải', 1, 7)
# x,,t,
# htuyan,tinhphúyên
# ('phúyên', 11, 17)
# htuyan,tinh,
# ('tuyan', 1, 6)
# h,,tinh,
# h,,tinh,
# x,văncẩs,hunghàttháibình
# ('tháibình', 16, 24)
# x,văncẩs,hunghàt,
# x,văncẩs,hunghàt,
# x,văncẩs,hunghàt,
# mườngla,sơnla
# ('sơnla', 8, 13)
# mườngla,,
# ('mườngla', 0, 7)
# ,,,
# ,,,
# õabnhngọc,tphốtuyhòa,phúyên
# ('phúyên', 21, 27)
# õabnhngọc,tphốtuyhòa,,
# ('tuyhòa', 14, 20)
# õabnhngọc,tphố,,,
# õabnhngọc,tphố,,,
# chươngdương,đônghưng
# chươngdương,đônghưng
# ('đônghưng', 12, 20)
# chươngdương,,
# ('chươngdương', 0, 11)
# ,,,
# nậmtin,diệnbiên
# nậmtin,diệnbiên
# nậmtin,diệnbiên
# ('nậmtin', 0, 6)
# ,,diệnbiên
# tpphanrang-tháplhàm,ninhthuận
# ('ninhthuận', 20, 29)
# tpphanrang-tháplhàm,,
# tpphanrang-tháplhàm,,
# tpphanrang-tháplhàm,,
# tânphươc,tingjiang
# tânphươc,tingjiang
# tânphươc,tingjiang
# tânphươc,tingjiang
# xanđức,huyênninhgiang,thảidương
# ('hảidương', 23, 31)
# xanđức,huyênninhgiang,t,
# ('ninhgiang', 12, 21)
# xanđức,huyên,,t,
# ('anđức', 1, 6)
# x,,huyên,,t,
# xtrungkiên,vĩnhphuúc
# xtrungkiên,vĩnhphuúc
# xtrungkiên,vĩnhphuúc
# ('trungkiên', 1, 10)
# x,,vĩnhphuúc
# x,đônglâm2,huyentiềnhải,ttháibình
# ('tháibình', 25, 33)
# x,đônglâm2,huyentiềnhải,t,
# ('tiềnhải', 16, 23)
# x,đônglâm2,huyen,,t,
# ('đônglâm', 2, 9)
# x,,2,huyen,,t,
# h,easúp,đắklắk
# ('đắklắk', 8, 14)
# h,easúp,,
# ('easúp', 2, 7)
# h,,,,
# h,,,,
# đứclĩnh,vũquang
# đứclĩnh,vũquang
# ('vũquang', 8, 15)
# đứclĩnh,,
# ('đứclĩnh', 0, 7)
# ,,,
# xquỳnhhôi,quỳnhphụ,tháibình
# ('tháibình', 19, 27)
# xquỳnhhôi,quỳnhphụ,,
# ('quỳnhphụ', 10, 18)
# xquỳnhhôi,,,,
# xquỳnhhôi,,,,
# ynphú,hbắcmê,vhàgiang
# ('hàgiang', 14, 21)
# ynphú,hbắcmê,v,
# ('bắcmê', 7, 12)
# ynphú,h,,v,
# ynphú,h,,v,
# xuântân,plongkhánh
# xuântân,plongkhánh
# ('longkhánh', 9, 18)
# xuântân,p,
# ('xuântân', 0, 7)
# ,,p,
# xiaake,phúthiện,tgialai
# ('gialai', 17, 23)
# xiaake,phúthiện,t,
# ('phúthiện', 7, 15)
# xiaake,,,t,
# ('iaake', 1, 6)
# x,,,,t,
# xtháisơn,anlão,hảiphòng
# ('hảiphòng', 15, 23)
# xtháisơn,anlão,,
# ('anlão', 9, 14)
# xtháisơn,,,,
# ('tháisơn', 1, 8)
# x,,,,,
# uar,krôngpa,gialai
# ('gialai', 12, 18)
# uar,krôngpa,,
# ('krôngpa', 4, 11)
# uar,,,,
# ('uar', 0, 3)
# ,,,,,
# heah'leo,đắklắk
# ('đắklắk', 9, 15)
# heah'leo,,
# ("eah'leo", 1, 8)
# h,,,
# h,,,
# phúđô,phúlươnz
# phúđô,phúlươnz
# phúđô,phúlươnz
# ('phúđô', 0, 5)
# ,,phúlươnz
# tháiha,hbavì,tphnội
# tháiha,hbavì,tphnội
# ('bavì', 8, 12)
# tháiha,h,,tphnội
# tháiha,h,,tphnội
# xphướchiệp,bếntre
# ('bếntre', 11, 17)
# xphướchiệp,,
# xphướchiệp,,
# ('phướchiệp', 1, 10)
# x,,,
# xhuyhạ,phùyêu,tsơnla
# ('sơnla', 15, 20)
# xhuyhạ,phùyêu,t,
# xhuyhạ,phùyêu,t,
# ('huyhạ', 1, 6)
# x,,phùyêu,t,
# ttrquỳnhcôi,hquỳnhphụ,tthaibình
# ttrquỳnhcôi,hquỳnhphụ,tthaibình
# ('quỳnhphụ', 13, 21)
# ttrquỳnhcôi,h,,tthaibình
# ('quỳnhcôi', 3, 11)
# ttr,,h,,tthaibình
# namđông,t,th
# namđông,t,th
# ('namđông', 0, 7)
# ,,t,th
# ,,t,th
# camnhân,yênbìnhtyênbái
# ('yênbái', 16, 22)
# camnhân,yênbìnht,
# ('yênbình', 8, 15)
# camnhân,,t,
# camnhân,,t,
# ttđứcan,đắksong,đắknông
# ('đắknông', 16, 23)
# ttđứcan,đắksong,,
# ('đắksong', 8, 15)
# ttđứcan,,,,
# ('đứcan', 2, 7)
# tt,,,,,
# ninhsở,thườngtin,tphànội
# ('hànội', 19, 24)
# ninhsở,thườngtin,tp,
# ninhsở,thườngtin,tp,
# ('ninhsở', 0, 6)
# ,,thườngtin,tp,
# xđòanđào,4phùcừ,thưngyên
# ('hưngyên', 17, 24)
# xđòanđào,4phùcừ,t,
# ('phùcừ', 10, 15)
# xđòanđào,4,,t,
# ('đòanđào', 1, 8)
# x,,4,,t,
# x,hươngliên,hươngkhê,hàtinh
# x,hươngliên,hươngkhê,hàtinh
# ('hươngkhê', 12, 20)
# x,hươngliên,,,hàtinh
# ('hươngliên', 2, 11)
# x,,,,,hàtinh
# hhòaiân,tbìnhdịnh
# hhòaiân,tbìnhdịnh
# ('hòaiân', 1, 7)
# h,,tbìnhdịnh
# h,,tbìnhdịnh
# phườnitràngminhq,kiếnanthànhphốhảiphòng
# ('hảiphòng', 31, 39)
# phườnitràngminhq,kiếnanthànhphố,
# ('kiếnan', 17, 23)
# phườnitràngminhq,,thànhphố,
# ('tràngminh', 6, 15)
# phườni,q,,thànhphố,
# bảnhojntamđườnglaichâu
# ('laichâu', 15, 22)
# bảnhojntamđường,
# ('tamđường', 7, 15)
# bảnhojn,,
# bảnhojn,,
# điênhải,đônghải,bạcliêu
# ('bạcliêu', 16, 23)
# điênhải,đônghải,,
# ('đônghải', 8, 15)
# điênhải,,,,
# điênhải,,,,
# hkbang,gialai
# ('gialai', 7, 13)
# hkbang,,
# ('kbang', 1, 6)
# h,,,
# h,,,
# x,thanhphongjc,thanhhóa
# ('thanhhóa', 15, 23)
# x,thanhphongjc,,
# x,thanhphongjc,,
# ('thanhphong', 2, 12)
# x,,jc,,
# bắctràmy,quảngnahm
# bắctràmy,quảngnahm
# ('bắctràmy', 0, 8)
# ,,quảngnahm
# ,,quảngnahm
# bìnhtrung,tlạngson
# bìnhtrung,tlạngson
# bìnhtrung,tlạngson
# ('bìnhtrung', 0, 9)
# ,,tlạngson
# bavì,tphànội
# ('hànội', 7, 12)
# bavì,tp,
# ('bavì', 0, 4)
# ,,tp,
# ,,tp,
# diễnchâu,nghệan
# ('nghệan', 9, 15)
# diễnchâu,,
# ('diễnchâu', 0, 8)
# ,,,
# ,,,
# muyệnchâuthành,đồngtháp
# ('đồngtháp', 15, 23)
# muyệnchâuthành,,
# ('châuthành', 5, 14)
# muyện,,,
# muyện,,,
# đôngthanhaneminh,kiengiang
# ('kiengiang', 17, 26)
# đôngthanhaneminh,,
# đôngthanhaneminh,,
# ('đông', 0, 4)
# ,thanhaneminh,,
# tânlĩnh,hlụcyên,tyênbái
# ('yênbái', 17, 23)
# tânlĩnh,hlụcyên,t,
# ('lụcyên', 9, 15)
# tânlĩnh,h,,t,
# ('tânlĩnh', 0, 7)
# ,,h,,t,
# pthủychâu,tx,hươngthủy,thừa,huế
# pthủychâu,tx,hươngthủy,thừa,huế
# ('hươngthủy', 13, 22)
# pthủychâu,tx,,,thừa,huế
# ('thủychâu', 1, 9)
# p,,tx,,,thừa,huế
# thitrấea,knốp,h,eakar
# thitrấea,knốp,h,eakar
# ('eakar', 16, 21)
# thitrấea,knốp,h,,
# thitrấea,knốp,h,,
# x,quếminh,hzuyệnquếsơn,quảngnam
# ('quảngnam', 23, 31)
# x,quếminh,hzuyệnquếsơn,,
# ('quếsơn', 16, 22)
# x,quếminh,hzuyện,,,
# ('quếminh', 2, 9)
# x,,,hzuyện,,,
# xngathanh,ngason,thanhqhóa
# xngathanh,ngason,thanhqhóa
# ('ngason', 10, 16)
# xngathanh,,,thanhqhóa
# ('ngathanh', 1, 9)
# x,,,,thanhqhóa
# phườngphúmỹ,thà6nhphốthủdầumột,tbìnhdương
# ('bìnhdương', 32, 41)
# phườngphúmỹ,thà6nhphốthủdầumột,t,
# ('thủdầumột', 21, 30)
# phườngphúmỹ,thà6nhphố,,t,
# ('phúmỹ', 6, 11)
# phường,,thà6nhphố,,t,
# lệthủy,tquảngbìnkh
# lệthủy,tquảngbìnkh
# ('lệthủy', 0, 6)
# ,,tquảngbìnkh
# ,,tquảngbìnkh
# ftânbình,dĩan
# ftânbình,dĩan
# ('dĩan', 9, 13)
# ftânbình,,
# ('tânbình', 1, 8)
# f,,,
# x2trungsơn,nghêan
# x2trungsơn,nghêan
# x2trungsơn,nghêan
# ('trungsơn', 2, 10)
# x2,,nghêan
# cônlôn,hnahang,ctuyênquang
# ('tuyênquang', 16, 26)
# cônlôn,hnahang,c,
# ('nahang', 8, 14)
# cônlôn,h,,c,
# ('cônlôn', 0, 6)
# ,,h,,c,
# tânhòa,h,phútân,tnhangiang
# ('angiang', 19, 26)
# tânhòa,h,phútân,tnh,
# ('phútân', 9, 15)
# tânhòa,h,,,tnh,
# ('tânhòa', 0, 6)
# ,,h,,,tnh,
# ------------------------------
#    correct  total  score / 10  max_time_sec  avg_time_sec
# 0     1287   1350        9.53        0.0102         0.001
# TEAM_NAME = 'DEFAULT_NAME_20250403_215321'
# EXCEL_FILE = 'DEFAULT_NAME_20250403_215321.xlsx'
# Excel file saved successfully.
